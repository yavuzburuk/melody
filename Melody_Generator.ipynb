# %% [markdown]
# ## Q=11, Leap<1/6
# ## Pickle dosyalarını oluşturuyor, midi dosyalarını yazıyor,
# ## Pickle dosyaları ext_3 ile açılıp skor dosyaları png olarak yazılıyor

# %%
import pandas as pd
import numpy as np
import random
import music21 as m21
from music21 import *
from IPython.display import Image
import pickle

# %%
us = m21.environment.UserSettings()
us['lilypondPath'] = 'C:/Program Files (x86)/LilyPond/usr/bin/lilypond.exe'
us['musescoreDirectPNGPath'] = 'C:/Program Files/MuseScore 3/bin/MuseScore3.exe'
us['musicxmlPath'] = 'C:/Program Files/MuseScore 3/bin/MuseScore3.exe'

# %%
# C4 ile başlıyor.

quarter_es = note.Rest()
quarter_es.duration.type = 'quarter'

eight_es = note.Rest()
eight_es.duration = duration.Duration(0.5)

w_C = note.Note('C4')
w_C.duration = duration.Duration(4)

q_G = note.Note('G3')
q_G.duration.type = 'quarter'
q_A = note.Note('A3')
q_A.duration.type = 'quarter'
q_B = note.Note('B3')
q_B.duration.type = 'quarter'
q_C = note.Note('C4')
q_C.duration.type = 'quarter'
q_D = note.Note('D4')
q_D.duration.type = 'quarter'
q_E = note.Note('E4')
q_E.duration.type = 'quarter'
q_F = note.Note('F4')
q_F.duration.type = 'quarter'
q_g = note.Note('G4')
q_g.duration.type = 'quarter'
q_a = note.Note('A4')
q_a.duration.type = 'quarter'

h_G = note.Note('G3')
h_G.duration = duration.Duration(2)
h_A = note.Note('A3')
h_A.duration = duration.Duration(2)
h_B = note.Note('B3')
h_B.duration = duration.Duration(2)
h_C = note.Note('C4')
h_C.duration = duration.Duration(2)
h_D = note.Note('D4')
h_D.duration = duration.Duration(2)
h_E = note.Note('E4')
h_E.duration = duration.Duration(2)
h_F = note.Note('F4')
h_F.duration = duration.Duration(2)
h_g = note.Note('G4')
h_g.duration = duration.Duration(2)
h_a = note.Note('A4')
h_a.duration = duration.Duration(2)

q3_G = note.Note('G3')
q3_G.duration = duration.Duration(1.5)
q3_A = note.Note('A3')
q3_A.duration = duration.Duration(1.5)
q3_B = note.Note('B3')
q3_B.duration = duration.Duration(1.5)
q3_C = note.Note('C4')
q3_C.duration = duration.Duration(1.5)
q3_D = note.Note('D4')
q3_D.duration = duration.Duration(1.5)
q3_E = note.Note('E4')
q3_E.duration = duration.Duration(1.5)
q3_F = note.Note('F4')
q3_F.duration = duration.Duration(1.5)
q3_g = note.Note('G4')
q3_g.duration = duration.Duration(1.5)
q3_a = note.Note('A4')
q3_a.duration = duration.Duration(1.5)


e_G = note.Note('G3')
e_G.duration = duration.Duration(0.5)
e_A = note.Note('A3')
e_A.duration = duration.Duration(0.5)
e_B = note.Note('B3')
e_B.duration = duration.Duration(0.5)
e_C = note.Note('C4')
e_C.duration = duration.Duration(0.5)
e_D = note.Note('D4')
e_D.duration = duration.Duration(0.5)
e_E = note.Note('E4')
e_E.duration = duration.Duration(0.5)
e_F = note.Note('F4')
e_F.duration = duration.Duration(0.5)
e_g = note.Note('G4')
e_g.duration = duration.Duration(0.5)
e_a = note.Note('A4')
e_a.duration = duration.Duration(0.5)

e3_G = note.Note('G3')
e3_G.duration = duration.Duration(0.75)
e3_A = note.Note('A3')
e3_A.duration = duration.Duration(0.75)
e3_B = note.Note('B3')
e3_B.duration = duration.Duration(0.75)
e3_C = note.Note('C4')
e3_C.duration = duration.Duration(0.75)
e3_D = note.Note('D4')
e3_D.duration = duration.Duration(0.75)
e3_E = note.Note('E4')
e3_E.duration = duration.Duration(0.75)
e3_F = note.Note('F4')
e3_F.duration = duration.Duration(0.75)
e3_g = note.Note('G4')
e3_g.duration = duration.Duration(0.75)
e3_a = note.Note('A4')
e3_a.duration = duration.Duration(0.75)

hq_G = note.Note('G3')
hq_G.duration = duration.Duration(3)
hq_A = note.Note('A3')
hq_A.duration = duration.Duration(3)
hq_B = note.Note('B3')
hq_B.duration = duration.Duration(3)
hq_C = note.Note('C4')
hq_C.duration = duration.Duration(3)
hq_D = note.Note('D4')
hq_D.duration = duration.Duration(3)
hq_E = note.Note('E4')
hq_E.duration = duration.Duration(3)
hq_F = note.Note('F4')
hq_F.duration = duration.Duration(3)
hq_g = note.Note('G4')
hq_g.duration = duration.Duration(3)
hq_a = note.Note('A4')
hq_a.duration = duration.Duration(3)

he_G = note.Note('G3')
he_G.duration = duration.Duration(2.5)
he_A = note.Note('A3')
he_A.duration = duration.Duration(2.5)
he_B = note.Note('B3')
he_B.duration = duration.Duration(2.5)
he_C = note.Note('C4')
he_C.duration = duration.Duration(2.5)
he_D = note.Note('D4')
he_D.duration = duration.Duration(2.5)
he_E = note.Note('E4')
he_E.duration = duration.Duration(2.5)
he_F = note.Note('F4')
he_F.duration = duration.Duration(2.5)
he_g = note.Note('G4')
he_g.duration = duration.Duration(2.5)
he_a = note.Note('A4')
he_a.duration = duration.Duration(2.5)

qs_G = note.Note('G3')
qs_G.duration = duration.Duration(1.25)
qs_A = note.Note('A3')
qs_A.duration = duration.Duration(1.25)
qs_B = note.Note('B3')
qs_B.duration = duration.Duration(1.25)
qs_C = note.Note('C4')
qs_C.duration = duration.Duration(1.25)
qs_D = note.Note('D4')
qs_D.duration = duration.Duration(1.25)
qs_E = note.Note('E4')
qs_E.duration = duration.Duration(1.25)
qs_F = note.Note('F4')
qs_F.duration = duration.Duration(1.25)
qs_g = note.Note('G4')
qs_g.duration = duration.Duration(1.25)
qs_a = note.Note('A4')
qs_a.duration = duration.Duration(1.25)

qdots_G = note.Note('G3')
qdots_G.duration = duration.Duration(1.75)
qdots_A = note.Note('A3')
qdots_A.duration = duration.Duration(1.75)
qdots_B = note.Note('B3')
qdots_B.duration = duration.Duration(1.75)
qdots_C = note.Note('C4')
qdots_C.duration = duration.Duration(1.75)
qdots_D = note.Note('D4')
qdots_D.duration = duration.Duration(1.75)
qdots_E = note.Note('E4')
qdots_E.duration = duration.Duration(1.75)
qdots_F = note.Note('F4')
qdots_F.duration = duration.Duration(1.75)
qdots_g = note.Note('G4')
qdots_g.duration = duration.Duration(1.75)
qdots_a = note.Note('A4')
qdots_a.duration = duration.Duration(1.75)

# %%
# 1 octave higher
# Starts with C5

quarter_es = note.Rest()
quarter_es.duration.type = 'quarter'

eight_es = note.Rest()
eight_es.duration = duration.Duration(0.5)

w_C = note.Note('C5')
w_C.duration = duration.Duration(4)

q_G = note.Note('G4')
q_G.duration.type = 'quarter'
q_A = note.Note('A4')
q_A.duration.type = 'quarter'
q_B = note.Note('B4')
q_B.duration.type = 'quarter'
q_C = note.Note('C5')
q_C.duration.type = 'quarter'
q_D = note.Note('D5')
q_D.duration.type = 'quarter'
q_E = note.Note('E5')
q_E.duration.type = 'quarter'
q_F = note.Note('F5')
q_F.duration.type = 'quarter'
q_g = note.Note('G5')
q_g.duration.type = 'quarter'
q_a = note.Note('A5')
q_a.duration.type = 'quarter'

h_G = note.Note('G4')
h_G.duration = duration.Duration(2)
h_A = note.Note('A4')
h_A.duration = duration.Duration(2)
h_B = note.Note('B4')
h_B.duration = duration.Duration(2)
h_C = note.Note('C5')
h_C.duration = duration.Duration(2)
h_D = note.Note('D5')
h_D.duration = duration.Duration(2)
h_E = note.Note('E5')
h_E.duration = duration.Duration(2)
h_F = note.Note('F5')
h_F.duration = duration.Duration(2)
h_g = note.Note('G5')
h_g.duration = duration.Duration(2)
h_a = note.Note('A5')
h_a.duration = duration.Duration(2)

q3_G = note.Note('G4')
q3_G.duration = duration.Duration(1.5)
q3_A = note.Note('A4')
q3_A.duration = duration.Duration(1.5)
q3_B = note.Note('B4')
q3_B.duration = duration.Duration(1.5)
q3_C = note.Note('C5')
q3_C.duration = duration.Duration(1.5)
q3_D = note.Note('D5')
q3_D.duration = duration.Duration(1.5)
q3_E = note.Note('E5')
q3_E.duration = duration.Duration(1.5)
q3_F = note.Note('F5')
q3_F.duration = duration.Duration(1.5)
q3_g = note.Note('G5')
q3_g.duration = duration.Duration(1.5)
q3_a = note.Note('A5')
q3_a.duration = duration.Duration(1.5)


e_G = note.Note('G4')
e_G.duration = duration.Duration(0.5)
e_A = note.Note('A4')
e_A.duration = duration.Duration(0.5)
e_B = note.Note('B4')
e_B.duration = duration.Duration(0.5)
e_C = note.Note('C5')
e_C.duration = duration.Duration(0.5)
e_D = note.Note('D5')
e_D.duration = duration.Duration(0.5)
e_E = note.Note('E5')
e_E.duration = duration.Duration(0.5)
e_F = note.Note('F5')
e_F.duration = duration.Duration(0.5)
e_g = note.Note('G5')
e_g.duration = duration.Duration(0.5)
e_a = note.Note('A5')
e_a.duration = duration.Duration(0.5)

e3_G = note.Note('G4')
e3_G.duration = duration.Duration(0.75)
e3_A = note.Note('A4')
e3_A.duration = duration.Duration(0.75)
e3_B = note.Note('B4')
e3_B.duration = duration.Duration(0.75)
e3_C = note.Note('C5')
e3_C.duration = duration.Duration(0.75)
e3_D = note.Note('D5')
e3_D.duration = duration.Duration(0.75)
e3_E = note.Note('E5')
e3_E.duration = duration.Duration(0.75)
e3_F = note.Note('F5')
e3_F.duration = duration.Duration(0.75)
e3_g = note.Note('G5')
e3_g.duration = duration.Duration(0.75)
e3_a = note.Note('A5')
e3_a.duration = duration.Duration(0.75)

hq_G = note.Note('G4')
hq_G.duration = duration.Duration(3)
hq_A = note.Note('A4')
hq_A.duration = duration.Duration(3)
hq_B = note.Note('B4')
hq_B.duration = duration.Duration(3)
hq_C = note.Note('C5')
hq_C.duration = duration.Duration(3)
hq_D = note.Note('D5')
hq_D.duration = duration.Duration(3)
hq_E = note.Note('E5')
hq_E.duration = duration.Duration(3)
hq_F = note.Note('F5')
hq_F.duration = duration.Duration(3)
hq_g = note.Note('G5')
hq_g.duration = duration.Duration(3)
hq_a = note.Note('A5')
hq_a.duration = duration.Duration(3)

he_G = note.Note('G4')
he_G.duration = duration.Duration(2.5)
he_A = note.Note('A4')
he_A.duration = duration.Duration(2.5)
he_B = note.Note('B4')
he_B.duration = duration.Duration(2.5)
he_C = note.Note('C5')
he_C.duration = duration.Duration(2.5)
he_D = note.Note('D5')
he_D.duration = duration.Duration(2.5)
he_E = note.Note('E5')
he_E.duration = duration.Duration(2.5)
he_F = note.Note('F5')
he_F.duration = duration.Duration(2.5)
he_g = note.Note('G5')
he_g.duration = duration.Duration(2.5)
he_a = note.Note('A5')
he_a.duration = duration.Duration(2.5)

qs_G = note.Note('G4')
qs_G.duration = duration.Duration(1.25)
qs_A = note.Note('A3')
qs_A.duration = duration.Duration(1.25)
qs_B = note.Note('B4')
qs_B.duration = duration.Duration(1.25)
qs_C = note.Note('C5')
qs_C.duration = duration.Duration(1.25)
qs_D = note.Note('D5')
qs_D.duration = duration.Duration(1.25)
qs_E = note.Note('E5')
qs_E.duration = duration.Duration(1.25)
qs_F = note.Note('F5')
qs_F.duration = duration.Duration(1.25)
qs_g = note.Note('G5')
qs_g.duration = duration.Duration(1.25)
qs_a = note.Note('A5')
qs_a.duration = duration.Duration(1.25)

qdots_G = note.Note('G4')
qdots_G.duration = duration.Duration(1.75)
qdots_A = note.Note('A4')
qdots_A.duration = duration.Duration(1.75)
qdots_B = note.Note('B4')
qdots_B.duration = duration.Duration(1.75)
qdots_C = note.Note('C5')
qdots_C.duration = duration.Duration(1.75)
qdots_D = note.Note('D5')
qdots_D.duration = duration.Duration(1.75)
qdots_E = note.Note('E5')
qdots_E.duration = duration.Duration(1.75)
qdots_F = note.Note('F5')
qdots_F.duration = duration.Duration(1.75)
qdots_g = note.Note('G5')
qdots_g.duration = duration.Duration(1.75)
qdots_a = note.Note('A5')
qdots_a.duration = duration.Duration(1.75)

# %%
note_conversion_df = pd.DataFrame({"Order" : [0 ,1, 2, 3, 4, 5, 6, 7, 8 ],
                                   "Note" : ["G", "A", "B", "C","D", "E","F", "g", "a"],
                                   "Half" : [h_G, h_A, h_B, h_C, h_D, h_E, h_F, h_g, h_a],
                                   "Quarter" : [q_G, q_A, q_B, q_C, q_D, q_E,q_F, q_g, q_a],
                                   "QuarterDot" : [q3_G, q3_A, q3_B, q3_C, q3_D, q3_E, q3_F, q3_g, q3_a],
                                   "Eigth" : [e_G, e_A, e_B, e_C, e_D, e_E, e_F, e_g, e_a],
                                   "EigthDot" : [e3_G, e3_A, e3_B, e3_C, e3_D , e3_E, e3_F, e3_g, e3_a],
                                   "HalfDot" : [hq_G, hq_A, hq_B, hq_C, hq_D , hq_E, hq_F, hq_g, hq_a],
                                   "HalfEigthDot" : [he_G, he_A, he_B, he_C, he_D , he_E, he_F, he_g, he_a],
                                   "QuarterSixteenth" : [qs_G, qs_A, qs_B, qs_C, qs_D , qs_E, qs_F, qs_g, qs_a],
                                   "QuarterDottedSixteenth" : [qdots_G, qdots_A, qdots_B, qdots_C, qdots_D , qdots_E, qdots_F, qdots_g, qdots_a]},
                                    index = ["5l", "6l", "7", "1","2", "3","4", "5", "6"])
note_conversion_df
# Out:
#     Order Note                   Half                Quarter  \
# 5l      0    G  <music21.note.Note G>  <music21.note.Note G>
# 6l      1    A  <music21.note.Note A>  <music21.note.Note A>
# 7       2    B  <music21.note.Note B>  <music21.note.Note B>
# 1       3    C  <music21.note.Note C>  <music21.note.Note C>
# 2       4    D  <music21.note.Note D>  <music21.note.Note D>
# 3       5    E  <music21.note.Note E>  <music21.note.Note E>
# 4       6    F  <music21.note.Note F>  <music21.note.Note F>
# 5       7    g  <music21.note.Note G>  <music21.note.Note G>
# 6       8    a  <music21.note.Note A>  <music21.note.Note A>
#
#                QuarterDot                  Eigth               EigthDot  \
# 5l  <music21.note.Note G>  <music21.note.Note G>  <music21.note.Note G>
# 6l  <music21.note.Note A>  <music21.note.Note A>  <music21.note.Note A>
# 7   <music21.note.Note B>  <music21.note.Note B>  <music21.note.Note B>
# ...

# %%
note_conversion_df.loc["5l"]["Half"]
# Out:
# <music21.note.Note G>

# %%
start_df = pd.read_csv("Start_rev.csv")
continue_df = pd.read_csv("Continueall_rev.csv")
cadence_df = pd.read_csv("Cadance_rev.csv")

start_df[["Bir","ve","Ki","ve2"]] = start_df[["Bir","ve","Ki","ve2"]].astype('str')
continue_df[["Bir","ve","Ki","ve2"]] = continue_df[["Bir","ve","Ki","ve2"]].astype('str')
cadence_df[["Bir","ve","Ki","ve2"]] = cadence_df[["Bir","ve","Ki","ve2"]].astype('str')

# %%
chord_progression = pd.DataFrame({'Start': ["I","I","I","I","I","I"], 
                                  'Continuation1': ["V","V","vi","I","IV","vi"],
                                  'Continuation2': ["I","vi","ii","IV","I","IV"],
                                  'Cadence1': ["V","V","V","V","V","V"],
                                  'Cadence2': ["I","I","I","I","I","I"]},
                                  index=['1', '2', '3', '4', '5','6'])

chord_progression
# Out:
#   Start Continuation1 Continuation2 Cadence1 Cadence2
# 1     I             V             I        V        I
# 2     I             V            vi        V        I
# 3     I            vi            ii        V        I
# 4     I             I            IV        V        I
# 5     I            IV             I        V        I
# 6     I            vi            IV        V        I

# %%
chord_sequence = pd.DataFrame({'5l': ["5l","","","1l",""], 
                               '6l': ["","5l","3l","","1l"],
                               '7': ["","","","3l",""],
                               '1': ["1","","5l","","3l"],
                               '2': ["","1","","5l",""],
                               '3': ["3","","","","5l"],
                               '4': ["","3","1","",""],
                               '5': ["5","","","1",""],
                               '6': ["","5","3","","1"]},
                               index=['I', 'ii', 'IV', 'V', 'vi'])

chord_sequence
# Out:
#     5l  6l   7   1   2   3  4  5  6
# I   5l           1       3     5
# ii      5l           1      3     5
# IV      3l      5l          1     3
# V   1l      3l      5l         1
# vi      1l      3l      5l        1

# %%
notes_sequence_df = pd.DataFrame({"5l": ["G"],
                                 "6l": ["A"],
                                 "7": ["B"],
                                 "1": ["C"],
                                 "2": ["D"],
                                 "3": ["E"],
                                 "4": ["F"],
                                 "5": ["g"],
                                 "6": ["a"],
                                 "nan": ["es"]},
                                 index=["Note"])
notes_sequence_df
# Out:
#      5l 6l  7  1  2  3  4  5  6 nan
# Note  G  A  B  C  D  E  F  g  a  es

# %%
def total_range(melody_to_analyze_df):

    min_note = note_conversion_df.Order[melody_to_analyze_df.Bir.iloc[0]]
    max_note = note_conversion_df.Order[melody_to_analyze_df.Bir.iloc[0]]
    
        
    for i in range(1, 4):
        if (melody_to_analyze_df.Bir.iloc[i]!="nan"):
            temp_note = note_conversion_df.Order[melody_to_analyze_df.Bir.iloc[i]]
            if temp_note>max_note:
                max_note = temp_note
            if temp_note<min_note:
                min_note = temp_note
        
    for i in range(4):    
        if (melody_to_analyze_df.ve.iloc[i]!="nan"):
            temp_note = note_conversion_df.Order[melody_to_analyze_df.ve.iloc[i]]
            if temp_note>max_note:
                max_note = temp_note
            if temp_note<min_note:
                min_note = temp_note
   
        if (melody_df.Ki.iloc[i]!="nan"):
            temp_note = note_conversion_df.Order[melody_to_analyze_df.Ki.iloc[i]]
            if temp_note>max_note:
                max_note = temp_note
            if temp_note<min_note:
                min_note = temp_note
            
        if (melody_df.ve2.iloc[i]!="nan"):
            temp_note = note_conversion_df.Order[melody_to_analyze_df.ve2.iloc[i]]
            if temp_note>max_note:
                max_note = temp_note
            if temp_note<min_note:
                min_note = temp_note        


    
    
    return max_note-min_note+1

# %%
def check_es(notes):
    
    es_length = "nan"
    if (notes.iloc[0]["Bir"] == "nan") & (notes.iloc[0]["ve"] == "nan") :
        es_length = "Quarter"
    elif notes.iloc[0]["Bir"] == "nan":
        es_length = "Eigth"
    
    return es_length

# %%
def measure_conversion(notes, s_measure):
    
    # x _ _ _
    if (notes.iloc[0]["ve"] == "nan") & (notes.iloc[0]["Ki"] == "nan") & (notes.iloc[0]["ve2"] == "nan"):
        s_measure.repeatAppend(note_conversion_df.loc[notes.iloc[0]["Bir"]]["Half"], 1)
    
    # x _ _ x
    elif (notes.iloc[0]["ve"] == "nan") & (notes.iloc[0]["Ki"] == "nan"):
        s_measure.repeatAppend(note_conversion_df.loc[notes.iloc[0]["Bir"]]["QuarterDot"], 1)
        s_measure.repeatAppend(note_conversion_df.loc[notes.iloc[0]["ve2"]]["Eigth"], 1)
    
    # x _ x -
    elif (notes.iloc[0]["ve"] == "nan") & (notes.iloc[0]["ve2"] == "nan"):
        s_measure.repeatAppend(note_conversion_df.loc[notes.iloc[0]["Bir"]]["Quarter"], 1)
        s_measure.repeatAppend(note_conversion_df.loc[notes.iloc[0]["Ki"]]["Quarter"], 1)
    
    
    # x _ x x
    elif (notes.iloc[0]["ve"] == "nan"):
        s_measure.repeatAppend(note_conversion_df.loc[notes.iloc[0]["Bir"]]["Quarter"], 1)
        s_measure.repeatAppend(note_conversion_df.loc[notes.iloc[0]["Ki"]]["Eigth"], 1)
        s_measure.repeatAppend(note_conversion_df.loc[notes.iloc[0]["ve2"]]["Eigth"], 1)
    
    # x x _ _
    elif (notes.iloc[0]["Ki"] == "nan") & (notes.iloc[0]["ve2"] == "nan"):
        s_measure.repeatAppend(note_conversion_df.loc[notes.iloc[0]["Bir"]]["Eigth"], 1)
        s_measure.repeatAppend(note_conversion_df.loc[notes.iloc[0]["ve"]]["QuarterDot"], 1)
    
    # x x _ x
    elif (notes.iloc[0]["Ki"] == "nan"):
        s_measure.repeatAppend(note_conversion_df.loc[notes.iloc[0]["Bir"]]["Eigth"], 1)
        s_measure.repeatAppend(note_conversion_df.loc[notes.iloc[0]["ve"]]["Quarter"], 1)
        s_measure.repeatAppend(note_conversion_df.loc[notes.iloc[0]["ve2"]]["Eigth"], 1)
    
    # x x x _
    elif (notes.iloc[0]["ve2"] == "nan"):           
        s_measure.repeatAppend(note_conversion_df.loc[notes.iloc[0]["Bir"]]["Eigth"], 1)
        s_measure.repeatAppend(note_conversion_df.loc[notes.iloc[0]["ve"]]["Eigth"], 1)
        s_measure.repeatAppend(note_conversion_df.loc[notes.iloc[0]["Ki"]]["Quarter"], 1)
    
    # x x x x
    else:
        s_measure.repeatAppend(note_conversion_df.loc[notes.iloc[0]["Bir"]]["Eigth"], 1)
        s_measure.repeatAppend(note_conversion_df.loc[notes.iloc[0]["ve"]]["Eigth"], 1)
        s_measure.repeatAppend(note_conversion_df.loc[notes.iloc[0]["Ki"]]["Eigth"], 1)
        s_measure.repeatAppend(note_conversion_df.loc[notes.iloc[0]["ve2"]]["Eigth"], 1)
        

    return s_measure

# %%
def write_score(melody):
    
    tie_score = False
    s_temp = stream.Stream()
    first_measure = melody.iloc[[0]]
    second_measure = melody.iloc[[1]]
    third_measure = melody.iloc[[2]]
    
    measure_1_2 = check_es(second_measure)
    measure_2_3 = check_es(third_measure)
    

    # First measure x _ _ _
    
    if (first_measure.iloc[0]["ve"] == "nan") & (first_measure.iloc[0]["Ki"] == "nan") & (first_measure.iloc[0]["ve2"] == "nan"):
        note_add = note_conversion_df.loc[first_measure.iloc[0]["Bir"]]["Half"]
        if (measure_1_2=="nan"):
            s_temp.repeatAppend(note_add,1)
        elif (measure_1_2=="Eigth"):
            tie_score = True
            note_add.tie = tie.Tie("start")
            s_temp.repeatAppend(note_add,1)
            note_add = note_conversion_df.loc[first_measure.iloc[0]["Bir"]]["Eigth"]
            note_add.tie = tie.Tie("stop")
            s_temp.repeatAppend(note_add,1)
        elif (measure_1_2=="Quarter"):
            tie_score = True
            note_add.tie = tie.Tie("start")
            s_temp.repeatAppend(note_add,1)
            note_add = note_conversion_df.loc[first_measure.iloc[0]["Bir"]]["Quarter"]
            note_add.tie = tie.Tie("stop")
            s_temp.repeatAppend(note_add,1)      
            
            
    # First measure x _ _ x
            
    elif (first_measure.iloc[0]["ve"] == "nan") & (first_measure.iloc[0]["Ki"] == "nan"):
        s_temp.repeatAppend(note_conversion_df.loc[first_measure.iloc[0]["Bir"]]["QuarterDot"],1)
        note_add = note_conversion_df.loc[first_measure.iloc[0]["ve2"]]["Eigth"]
        if (measure_1_2=="nan"):
            s_temp.repeatAppend(note_add,1)
        elif (measure_1_2=="Eigth"):
            tie_score = True
            note_add.tie = tie.Tie("start")
            s_temp.repeatAppend(note_add,1)
            note_add = note_conversion_df.loc[first_measure.iloc[0]["ve2"]]["Eigth"]
            note_add.tie = tie.Tie("stop")
            s_temp.repeatAppend(note_add,1)
        elif (measure_1_2=="Quarter"):
            tie_score = True
            note_add.tie = tie.Tie("start")
            s_temp.repeatAppend(note_add,1)
            note_add = note_conversion_df.loc[first_measure.iloc[0]["ve2"]]["Quarter"]
            note_add.tie = tie.Tie("stop")
            s_temp.repeatAppend(note_add,1)      

    # First measure x _ x _
    
    elif (first_measure.iloc[0]["ve"] == "nan") & (first_measure.iloc[0]["ve2"] == "nan"):
        s_temp.repeatAppend(note_conversion_df.loc[first_measure.iloc[0]["Bir"]]["Quarter"],1)
        note_add = note_conversion_df.loc[first_measure.iloc[0]["Ki"]]["Quarter"]
        if (measure_1_2=="nan"):
            s_temp.repeatAppend(note_add,1)
        elif (measure_1_2=="Eigth"):
            tie_score = True
            note_add.tie = tie.Tie("start")
            s_temp.repeatAppend(note_add,1)
            note_add = note_conversion_df.loc[first_measure.iloc[0]["Ki"]]["Eigth"]
            note_add.tie = tie.Tie("stop")
            s_temp.repeatAppend(note_add,1)
        elif (measure_1_2=="Quarter"):
            tie_score = True
            note_add.tie = tie.Tie("start")
            s_temp.repeatAppend(note_add,1)
            note_add = note_conversion_df.loc[first_measure.iloc[0]["Ki"]]["Quarter"]
            note_add.tie = tie.Tie("stop")
            s_temp.repeatAppend(note_add,1)      
        
    # First measure x _ x x   

    elif (first_measure.iloc[0]["ve"] == "nan"):
        s_temp.repeatAppend(note_conversion_df.loc[first_measure.iloc[0]["Bir"]]["Quarter"],1)
        s_temp.repeatAppend(note_conversion_df.loc[first_measure.iloc[0]["Ki"]]["Eigth"],1)
        note_add = note_conversion_df.loc[first_measure.iloc[0]["ve2"]]["Eigth"]
        if (measure_1_2=="nan"):
            s_temp.repeatAppend(note_add,1)
        elif (measure_1_2=="Eigth"):
            tie_score = True
            note_add.tie = tie.Tie("start")
            s_temp.repeatAppend(note_add,1)
            note_add = note_conversion_df.loc[first_measure.iloc[0]["ve2"]]["Eigth"]
            note_add.tie = tie.Tie("stop")
            s_temp.repeatAppend(note_add,1)
        elif (measure_1_2=="Quarter"):
            tie_score = True
            note_add.tie = tie.Tie("start")
            s_temp.repeatAppend(note_add,1)
            note_add = note_conversion_df.loc[first_measure.iloc[0]["ve2"]]["Quarter"]
            note_add.tie = tie.Tie("stop")
            s_temp.repeatAppend(note_add,1)   
    
    # First measure x x _ _
    
    elif (first_measure.iloc[0]["Ki"] == "nan") & (first_measure.iloc[0]["ve2"] == "nan"):
        s_temp.repeatAppend(note_conversion_df.loc[first_measure.iloc[0]["Bir"]]["Eigth"],1)
        note_add = note_conversion_df.loc[first_measure.iloc[0]["ve"]]["QuarterDot"]
        if (measure_1_2=="nan"):
            s_temp.repeatAppend(note_add,1)
        elif (measure_1_2=="Eigth"):
            tie_score = True
            note_add.tie = tie.Tie("start")
            s_temp.repeatAppend(note_add,1)
            note_add = note_conversion_df.loc[first_measure.iloc[0]["ve"]]["Eigth"]
            note_add.tie = tie.Tie("stop")
            s_temp.repeatAppend(note_add,1)
        elif (measure_1_2=="Quarter"):
            tie_score = True
            note_add.tie = tie.Tie("start")
            s_temp.repeatAppend(note_add,1)
            note_add = note_conversion_df.loc[first_measure.iloc[0]["ve"]]["Quarter"]
            note_add.tie = tie.Tie("stop")
            s_temp.repeatAppend(note_add,1)      

    # First measure x x _ x        
            
    elif (first_measure.iloc[0]["Ki"] == "nan"):
        s_temp.repeatAppend(note_conversion_df.loc[first_measure.iloc[0]["Bir"]]["Eigth"],1)
        s_temp.repeatAppend(note_conversion_df.loc[first_measure.iloc[0]["ve"]]["Quarter"],1)
        note_add = note_conversion_df.loc[first_measure.iloc[0]["ve2"]]["Eigth"]
        if (measure_1_2=="nan"):
            s_temp.repeatAppend(note_add,1)
        elif (measure_1_2=="Eigth"):
            tie_score = True
            note_add.tie = tie.Tie("start")
            s_temp.repeatAppend(note_add,1)
            note_add = note_conversion_df.loc[first_measure.iloc[0]["ve2"]]["Eigth"]
            note_add.tie = tie.Tie("stop")
            s_temp.repeatAppend(note_add,1)
        elif (measure_1_2=="Quarter"):
            tie_score = True
            note_add.tie = tie.Tie("start")
            s_temp.repeatAppend(note_add,1)
            note_add = note_conversion_df.loc[first_measure.iloc[0]["ve2"]]["Quarter"]
            note_add.tie = tie.Tie("stop")
            s_temp.repeatAppend(note_add,1)      

    # First measure x x x _        
            
    elif (first_measure.iloc[0]["ve2"] == "nan"):           
        s_temp.repeatAppend(note_conversion_df.loc[first_measure.iloc[0]["Bir"]]["Eigth"],1)
        s_temp.repeatAppend(note_conversion_df.loc[first_measure.iloc[0]["ve"]]["Eigth"],1)
        note_add = note_conversion_df.loc[first_measure.iloc[0]["Ki"]]["Quarter"]
        if (measure_1_2=="nan"):
            s_temp.repeatAppend(note_add,1)
        elif (measure_1_2=="Eigth"):
            tie_score = True
            note_add.tie = tie.Tie("start")
            s_temp.repeatAppend(note_add,1)
            note_add = note_conversion_df.loc[first_measure.iloc[0]["Ki"]]["Eigth"]
            note_add.tie = tie.Tie("stop")
            s_temp.repeatAppend(note_add,1)
        elif (measure_1_2=="Quarter"):
            tie_score = True
            note_add.tie = tie.Tie("start")
            s_temp.repeatAppend(note_add,1)
            note_add = note_conversion_df.loc[first_measure.iloc[0]["Ki"]]["Quarter"]
            note_add.tie = tie.Tie("stop")
            s_temp.repeatAppend(note_add,1)      

    # First measure x x x x
                
    else:
        s_temp.repeatAppend(note_conversion_df.loc[first_measure.iloc[0]["Bir"]]["Eigth"],1)
        s_temp.repeatAppend(note_conversion_df.loc[first_measure.iloc[0]["ve"]]["Eigth"],1)
        s_temp.repeatAppend(note_conversion_df.loc[first_measure.iloc[0]["Ki"]]["Eigth"],1)
        note_add = note_conversion_df.loc[first_measure.iloc[0]["ve2"]]["Eigth"]
        if (measure_1_2=="nan"):
            s_temp.repeatAppend(note_add,1)
        elif (measure_1_2=="Eigth"):
            tie_score = True
            note_add.tie = tie.Tie("start")
            s_temp.repeatAppend(note_add,1)
            note_add = note_conversion_df.loc[first_measure.iloc[0]["ve2"]]["Eigth"]
            note_add.tie = tie.Tie("stop")
            s_temp.repeatAppend(note_add,1)
        elif (measure_1_2=="Quarter"):
            tie_score = True
            note_add.tie = tie.Tie("start")
            s_temp.repeatAppend(note_add,1)
            note_add = note_conversion_df.loc[first_measure.iloc[0]["ve2"]]["Quarter"]
            note_add.tie = tie.Tie("stop")
            s_temp.repeatAppend(note_add,1)      

# 2nd Measure        


    # Seconda measure x _ _ _   

    if (measure_1_2=="nan"):
        if (second_measure.iloc[0]["ve"] == "nan") & (second_measure.iloc[0]["Ki"] == "nan") & (second_measure.iloc[0]["ve2"] == "nan"):
            note_add = note_conversion_df.loc[second_measure.iloc[0]["Bir"]]["Half"]
            if (measure_2_3=="nan"):
                s_temp.repeatAppend(note_add,1)
            elif (measure_2_3=="Eigth"):
                tie_score = True
                note_add.tie = tie.Tie("start")
                s_temp.repeatAppend(note_add,1)
                note_add = note_conversion_df.loc[second_measure.iloc[0]["Bir"]]["Eigth"]
                note_add.tie = tie.Tie("stop")
                s_temp.repeatAppend(note_add,1)
            elif (measure_2_3=="Quarter"):
                tie_score = True
                note_add.tie = tie.Tie("start")
                s_temp.repeatAppend(note_add,1)
                note_add = note_conversion_df.loc[second_measure.iloc[0]["Bir"]]["Quarter"]
                note_add.tie = tie.Tie("stop")
                s_temp.repeatAppend(note_add,1)      
            
            
        # Seconda measure x _ _ x
            
        elif (second_measure.iloc[0]["ve"] == "nan") & (second_measure.iloc[0]["Ki"] == "nan"):
            s_temp.repeatAppend(note_conversion_df.loc[second_measure.iloc[0]["Bir"]]["QuarterDot"],1)
            note_add = note_conversion_df.loc[second_measure.iloc[0]["ve2"]]["Eigth"]
            if (measure_2_3=="nan"):
                s_temp.repeatAppend(note_add,1)
            elif (measure_2_3=="Eigth"):
                tie_score = True
                note_add.tie = tie.Tie("start")
                s_temp.repeatAppend(note_add,1)
                note_add = note_conversion_df.loc[second_measure.iloc[0]["ve2"]]["Eigth"]
                note_add.tie = tie.Tie("stop")
                s_temp.repeatAppend(note_add,1)
            elif (measure_2_3=="Quarter"):
                tie_score = True
                note_add.tie = tie.Tie("start")
                s_temp.repeatAppend(note_add,1)
                note_add = note_conversion_df.loc[second_measure.iloc[0]["ve2"]]["Quarter"]
                note_add.tie = tie.Tie("stop")
                s_temp.repeatAppend(note_add,1)      

        
        # Seconda measure x _ x _
        
        elif (second_measure.iloc[0]["ve"] == "nan") & (second_measure.iloc[0]["ve2"] == "nan"):
            s_temp.repeatAppend(note_conversion_df.loc[second_measure.iloc[0]["Bir"]]["Quarter"],1)
            note_add = note_conversion_df.loc[second_measure.iloc[0]["Ki"]]["Quarter"]
            if (measure_2_3=="nan"):
                s_temp.repeatAppend(note_add,1)
            elif (measure_2_3=="Eigth"):
                tie_score = True
                note_add.tie = tie.Tie("start")
                s_temp.repeatAppend(note_add,1)
                note_add = note_conversion_df.loc[second_measure.iloc[0]["Ki"]]["Eigth"]
                note_add.tie = tie.Tie("stop")
                s_temp.repeatAppend(note_add,1)
            elif (measure_2_3=="Quarter"):
                tie_score = True
                note_add.tie = tie.Tie("start")
                s_temp.repeatAppend(note_add,1)
                note_add = note_conversion_df.loc[second_measure.iloc[0]["Ki"]]["Quarter"]
                note_add.tie = tie.Tie("stop")
                s_temp.repeatAppend(note_add,1)      
        
        # Seconda measure x _ x x
        
        elif (second_measure.iloc[0]["ve"] == "nan"):
            s_temp.repeatAppend(note_conversion_df.loc[second_measure.iloc[0]["Bir"]]["Quarter"],1)
            s_temp.repeatAppend(note_conversion_df.loc[second_measure.iloc[0]["Ki"]]["Eigth"],1)
            note_add = note_conversion_df.loc[second_measure.iloc[0]["ve2"]]["Eigth"]
            if (measure_2_3=="nan"):
                s_temp.repeatAppend(note_add,1)
            elif (measure_2_3=="Eigth"):
                tie_score = True
                note_add.tie = tie.Tie("start")
                s_temp.repeatAppend(note_add,1)
                note_add = note_conversion_df.loc[second_measure.iloc[0]["ve2"]]["Eigth"]
                note_add.tie = tie.Tie("stop")
                s_temp.repeatAppend(note_add,1)
            elif (measure_2_3=="Quarter"):
                tie_score = True
                note_add.tie = tie.Tie("start")
                s_temp.repeatAppend(note_add,1)
                note_add = note_conversion_df.loc[second_measure.iloc[0]["ve2"]]["Quarter"]
                note_add.tie = tie.Tie("stop")
                s_temp.repeatAppend(note_add,1)   
        
        # Seconda measure x x _ _
        
        elif (second_measure.iloc[0]["Ki"] == "nan") & (second_measure.iloc[0]["ve2"] == "nan"):
            s_temp.repeatAppend(note_conversion_df.loc[second_measure.iloc[0]["Bir"]]["Eigth"],1)
            note_add = note_conversion_df.loc[second_measure.iloc[0]["ve"]]["QuarterDot"]
            if (measure_2_3=="nan"):
                s_temp.repeatAppend(note_add,1)
            elif (measure_2_3=="Eigth"):
                tie_score = True
                note_add.tie = tie.Tie("start")
                s_temp.repeatAppend(note_add,1)
                note_add = note_conversion_df.loc[second_measure.iloc[0]["ve"]]["Eigth"]
                note_add.tie = tie.Tie("stop")
                s_temp.repeatAppend(note_add,1)
            elif (measure_2_3=="Quarter"):
                tie_score = True
                note_add.tie = tie.Tie("start")
                s_temp.repeatAppend(note_add,1)
                note_add = note_conversion_df.loc[second_measure.iloc[0]["ve"]]["Quarter"]
                note_add.tie = tie.Tie("stop")
                s_temp.repeatAppend(note_add,1)      

         # Second measure x x _ x
        
        elif (second_measure.iloc[0]["Ki"] == "nan"):
            s_temp.repeatAppend(note_conversion_df.loc[second_measure.iloc[0]["Bir"]]["Eigth"],1)
            s_temp.repeatAppend(note_conversion_df.loc[second_measure.iloc[0]["ve"]]["Quarter"],1)
            note_add = note_conversion_df.loc[second_measure.iloc[0]["ve2"]]["Eigth"]
            if (measure_2_3=="nan"):
                s_temp.repeatAppend(note_add,1)
            elif (measure_2_3=="Eigth"):
                tie_score = True
                note_add.tie = tie.Tie("start")
                s_temp.repeatAppend(note_add,1)
                note_add = note_conversion_df.loc[second_measure.iloc[0]["ve2"]]["Eigth"]
                note_add.tie = tie.Tie("stop")
                s_temp.repeatAppend(note_add,1)
            elif (measure_2_3=="Quarter"):
                tie_score = True
                note_add.tie = tie.Tie("start")
                s_temp.repeatAppend(note_add,1)
                note_add = note_conversion_df.loc[second_measure.iloc[0]["ve2"]]["Quarter"]
                note_add.tie = tie.Tie("stop")
                s_temp.repeatAppend(note_add,1)      

         # Second measure x x x _  
            
        elif (second_measure.iloc[0]["ve2"] == "nan"):           
            s_temp.repeatAppend(note_conversion_df.loc[second_measure.iloc[0]["Bir"]]["Eigth"],1)
            s_temp.repeatAppend(note_conversion_df.loc[second_measure.iloc[0]["ve"]]["Eigth"],1)
            note_add = note_conversion_df.loc[second_measure.iloc[0]["Ki"]]["Quarter"]
            if (measure_2_3=="nan"):
                s_temp.repeatAppend(note_add,1)
            elif (measure_2_3=="Eigth"):
                tie_score = True
                note_add.tie = tie.Tie("start")
                s_temp.repeatAppend(note_add,1)
                note_add = note_conversion_df.loc[second_measure.iloc[0]["Ki"]]["Eigth"]
                note_add.tie = tie.Tie("stop")
                s_temp.repeatAppend(note_add,1)
            elif (measure_2_3=="Quarter"):
                tie_score = True
                note_add.tie = tie.Tie("start")
                s_temp.repeatAppend(note_add,1)
                note_add = note_conversion_df.loc[second_measure.iloc[0]["Ki"]]["Quarter"]
                note_add.tie = tie.Tie("stop")
                s_temp.repeatAppend(note_add,1)      

        # Second measure x x x x 
        
        else:
            s_temp.repeatAppend(note_conversion_df.loc[second_measure.iloc[0]["Bir"]]["Eigth"],1)
            s_temp.repeatAppend(note_conversion_df.loc[second_measure.iloc[0]["ve"]]["Eigth"],1)
            s_temp.repeatAppend(note_conversion_df.loc[second_measure.iloc[0]["Ki"]]["Eigth"],1)
            note_add = note_conversion_df.loc[second_measure.iloc[0]["ve2"]]["Eigth"]
            if (measure_2_3=="nan"):
                s_temp.repeatAppend(note_add,1)
            elif (measure_2_3=="Eigth"):
                tie_score = True
                note_add.tie = tie.Tie("start")
                s_temp.repeatAppend(note_add,1)
                note_add = note_conversion_df.loc[second_measure.iloc[0]["ve2"]]["Eigth"]
                note_add.tie = tie.Tie("stop")
                s_temp.repeatAppend(note_add,1)
            elif (measure_2_3=="Quarter"):
                tie_score = True
                note_add.tie = tie.Tie("start")
                s_temp.repeatAppend(note_add,1)
                note_add = note_conversion_df.loc[second_measure.iloc[0]["ve2"]]["Quarter"]
                note_add.tie = tie.Tie("stop")
                s_temp.repeatAppend(note_add,1)      

    # ilk Nota Eight Es
    
    elif (measure_1_2=="Eigth"):
        
        #2nd measure _ x _ _
        
        if (second_measure.iloc[0]["Ki"] == "nan") & (second_measure.iloc[0]["ve2"] == "nan"):
            note_add = note_conversion_df.loc[second_measure.iloc[0]["ve"]]["QuarterDot"]
            if (measure_2_3=="nan"):
                s_temp.repeatAppend(note_add,1)
            elif (measure_2_3=="Eigth"):
                tie_score = True
                note_add.tie = tie.Tie("start")
                s_temp.repeatAppend(note_add,1)
                note_add = note_conversion_df.loc[second_measure.iloc[0]["ve"]]["Eigth"]
                note_add.tie = tie.Tie("stop")
                s_temp.repeatAppend(note_add,1)
            elif (measure_2_3=="Quarter"):
                tie_score = True
                note_add.tie = tie.Tie("start")
                s_temp.repeatAppend(note_add,1)
                note_add = note_conversion_df.loc[second_measure.iloc[0]["ve"]]["Quarter"]
                note_add.tie = tie.Tie("stop")
                s_temp.repeatAppend(note_add,1)      

        #2nd measure _ x _ x 
        
        elif (second_measure.iloc[0]["Ki"] == "nan"):
            s_temp.repeatAppend(note_conversion_df.loc[second_measure.iloc[0]["ve"]]["Quarter"],1)
            note_add = note_conversion_df.loc[second_measure.iloc[0]["ve2"]]["Eigth"]
            if (measure_2_3=="nan"):
                s_temp.repeatAppend(note_add,1)
            elif (measure_2_3=="Eigth"):
                tie_score = True
                note_add.tie = tie.Tie("start")
                s_temp.repeatAppend(note_add,1)
                note_add = note_conversion_df.loc[second_measure.iloc[0]["ve2"]]["Eigth"]
                note_add.tie = tie.Tie("stop")
                s_temp.repeatAppend(note_add,1)
            elif (measure_2_3=="Quarter"):
                tie_score = True
                note_add.tie = tie.Tie("start")
                s_temp.repeatAppend(note_add,1)
                note_add = note_conversion_df.loc[second_measure.iloc[0]["ve2"]]["Quarter"]
                note_add.tie = tie.Tie("stop")
                s_temp.repeatAppend(note_add,1)      

        #2nd measure _ x x _    
            
        elif (second_measure.iloc[0]["ve2"] == "nan"):           
            s_temp.repeatAppend(note_conversion_df.loc[second_measure.iloc[0]["ve"]]["Eigth"],1)
            note_add = note_conversion_df.loc[second_measure.iloc[0]["Ki"]]["Quarter"]
            if (measure_2_3=="nan"):
                s_temp.repeatAppend(note_add,1)
            elif (measure_2_3=="Eigth"):
                tie_score = True
                note_add.tie = tie.Tie("start")
                s_temp.repeatAppend(note_add,1)
                note_add = note_conversion_df.loc[second_measure.iloc[0]["Ki"]]["Eigth"]
                note_add.tie = tie.Tie("stop")
                s_temp.repeatAppend(note_add,1)
            elif (measure_2_3=="Quarter"):
                tie_score = True
                note_add.tie = tie.Tie("start")
                s_temp.repeatAppend(note_add,1)
                note_add = note_conversion_df.loc[second_measure.iloc[0]["Ki"]]["Quarter"]
                note_add.tie = tie.Tie("stop")
                s_temp.repeatAppend(note_add,1)      

        #2nd measure _ x x x        
            
        else:
            s_temp.repeatAppend(note_conversion_df.loc[second_measure.iloc[0]["ve"]]["Eigth"],1)
            s_temp.repeatAppend(note_conversion_df.loc[second_measure.iloc[0]["Ki"]]["Eigth"],1)
            note_add = note_conversion_df.loc[second_measure.iloc[0]["ve2"]]["Eigth"]
            if (measure_2_3=="nan"):
                s_temp.repeatAppend(note_add,1)
            elif (measure_2_3=="Eigth"):
                tie_score = True
                note_add.tie = tie.Tie("start")
                s_temp.repeatAppend(note_add,1)
                note_add = note_conversion_df.loc[second_measure.iloc[0]["ve2"]]["Eigth"]
                note_add.tie = tie.Tie("stop")
                s_temp.repeatAppend(note_add,1)
            elif (measure_2_3=="Quarter"):
                tie_score = True
                note_add.tie = tie.Tie("start")
                s_temp.repeatAppend(note_add,1)
                note_add = note_conversion_df.loc[second_measure.iloc[0]["ve2"]]["Quarter"]
                note_add.tie = tie.Tie("stop")
                s_temp.repeatAppend(note_add,1)      
        
    # ilk Nota Quarter Es
    
    elif (measure_1_2=="Quarter"):
        
        #2nd measure _ _ x _ 
        
        if (second_measure.iloc[0]["ve2"] == "nan"):           
            note_add = note_conversion_df.loc[second_measure.iloc[0]["Ki"]]["Quarter"]
            if (measure_2_3=="nan"):
                s_temp.repeatAppend(note_add,1)
            elif (measure_2_3=="Eigth"):
                tie_score = True
                note_add.tie = tie.Tie("start")
                s_temp.repeatAppend(note_add,1)
                note_add = note_conversion_df.loc[second_measure.iloc[0]["Ki"]]["Eigth"]
                note_add.tie = tie.Tie("stop")
                s_temp.repeatAppend(note_add,1)
            elif (measure_2_3=="Quarter"):
                tie_score = True
                note_add.tie = tie.Tie("start")
                s_temp.repeatAppend(note_add,1)
                note_add = note_conversion_df.loc[second_measure.iloc[0]["Ki"]]["Quarter"]
                note_add.tie = tie.Tie("stop")
                s_temp.repeatAppend(note_add,1)      

        #2nd measure _ _ x x        
            
        else:
           
            s_temp.repeatAppend(note_conversion_df.loc[second_measure.iloc[0]["Ki"]]["Eigth"],1)
            #note_add.tie = tie.Tie("stop")
            note_add = note_conversion_df.loc[second_measure.iloc[0]["ve2"]]["Eigth"]
            #note_add.tie = tie.Tie("stop")
            if (measure_2_3=="nan"):
                s_temp.repeatAppend(note_add,1)
            elif (measure_2_3=="Eigth"):
                tie_score = True
                note_add.tie = tie.Tie("start")
                s_temp.repeatAppend(note_add,1)
                note_add = note_conversion_df.loc[second_measure.iloc[0]["ve2"]]["Eigth"]
                note_add.tie = tie.Tie("stop")
                s_temp.repeatAppend(note_add,1)
                
            elif (measure_2_3=="Quarter"):
                tie_score = True
                note_add.tie = tie.Tie("start")
                s_temp.repeatAppend(note_add,1)
                note_add = note_conversion_df.loc[second_measure.iloc[0]["ve2"]]["Quarter"]
                note_add.tie = tie.Tie("stop")
                s_temp.repeatAppend(note_add,1)
                
        
# 3rd measure

  
    #Third Measure x _ _ _  
    
    if (measure_2_3=="nan"):
        if (third_measure.iloc[0]["ve"] == "nan") & (third_measure.iloc[0]["Ki"] == "nan") & (third_measure.iloc[0]["ve2"] == "nan"):
            note_add = note_conversion_df.loc[third_measure.iloc[0]["Bir"]]["Half"]
            s_temp.repeatAppend(note_add,1)
              
         #Third Measure x _ _ x   
        
        elif (third_measure.iloc[0]["ve"] == "nan") & (third_measure.iloc[0]["Ki"] == "nan"):
            s_temp.repeatAppend(note_conversion_df.loc[third_measure.iloc[0]["Bir"]]["QuarterDot"],1)
            note_add = note_conversion_df.loc[third_measure.iloc[0]["ve2"]]["Eigth"]
            s_temp.repeatAppend(note_add,1)
             
        #Third Measure x _ x _ 
            
        elif (third_measure.iloc[0]["ve"] == "nan") & (third_measure.iloc[0]["ve2"] == "nan"):
            s_temp.repeatAppend(note_conversion_df.loc[third_measure.iloc[0]["Bir"]]["Quarter"],1)
            note_add = note_conversion_df.loc[third_measure.iloc[0]["Ki"]]["Quarter"]
            s_temp.repeatAppend(note_add,1)
              
        #Third Measure x _ x x
        
        elif (third_measure.iloc[0]["ve"] == "nan"):
            s_temp.repeatAppend(note_conversion_df.loc[third_measure.iloc[0]["Bir"]]["Quarter"],1)
            s_temp.repeatAppend(note_conversion_df.loc[third_measure.iloc[0]["Ki"]]["Eigth"],1)
            note_add = note_conversion_df.loc[third_measure.iloc[0]["ve2"]]["Eigth"]
            s_temp.repeatAppend(note_add,1)
         
        #Third Measure x x _ _
            
        elif (third_measure.iloc[0]["Ki"] == "nan") & (third_measure.iloc[0]["ve2"] == "nan"):
            s_temp.repeatAppend(note_conversion_df.loc[third_measure.iloc[0]["Bir"]]["Eigth"],1)
            note_add = note_conversion_df.loc[third_measure.iloc[0]["ve"]]["QuarterDot"]
            s_temp.repeatAppend(note_add,1)
            
        #Third Measure x x _ x
        
        elif (third_measure.iloc[0]["Ki"] == "nan"):
            s_temp.repeatAppend(note_conversion_df.loc[third_measure.iloc[0]["Bir"]]["Eigth"],1)
            s_temp.repeatAppend(note_conversion_df.loc[third_measure.iloc[0]["ve"]]["Quarter"],1)
            note_add = note_conversion_df.loc[third_measure.iloc[0]["ve2"]]["Eigth"]
            s_temp.repeatAppend(note_add,1)
            
        #Third Measure x x x -   
            
        elif (third_measure.iloc[0]["ve2"] == "nan"):           
            s_temp.repeatAppend(note_conversion_df.loc[third_measure.iloc[0]["Bir"]]["Eigth"],1)
            s_temp.repeatAppend(note_conversion_df.loc[third_measure.iloc[0]["ve"]]["Eigth"],1)
            note_add = note_conversion_df.loc[third_measure.iloc[0]["Ki"]]["Quarter"]
            s_temp.repeatAppend(note_add,1)
        
        #Third Measure x x x x 
        else:
            s_temp.repeatAppend(note_conversion_df.loc[third_measure.iloc[0]["Bir"]]["Eigth"],1)
            s_temp.repeatAppend(note_conversion_df.loc[third_measure.iloc[0]["ve"]]["Eigth"],1)
            s_temp.repeatAppend(note_conversion_df.loc[third_measure.iloc[0]["Ki"]]["Eigth"],1)
            s_temp.repeatAppend(note_conversion_df.loc[third_measure.iloc[0]["ve2"]]["Eigth"],1)
          
            
    # ilk Nota Eight Es
    
    elif (measure_2_3=="Eigth"):
        
        #Third Measure _ x _ _  
        
        if (third_measure.iloc[0]["Ki"] == "nan") & (third_measure.iloc[0]["ve2"] == "nan"):
            s_temp.repeatAppend(note_conversion_df.loc[third_measure.iloc[0]["ve"]]["QuarterDot"],1)
          
         
        #Third Measure _ x _ x  
            
        elif (third_measure.iloc[0]["Ki"] == "nan"):
            s_temp.repeatAppend(note_conversion_df.loc[third_measure.iloc[0]["ve"]]["Quarter"],1)
            s_temp.repeatAppend(note_conversion_df.loc[second_measure.iloc[0]["ve2"]]["Eigth"],1)
             

        #Third Measure _ x x _      
            
        elif (third_measure.iloc[0]["ve2"] == "nan"):           
            s_temp.repeatAppend(note_conversion_df.loc[third_measure.iloc[0]["ve"]]["Eigth"],1)
            s_temp.repeatAppend(note_conversion_df.loc[third_measure.iloc[0]["Ki"]]["Quarter"],1)
                         
        #Third Measure _ x x x  
            
        else:
            s_temp.repeatAppend(note_conversion_df.loc[third_measure.iloc[0]["ve"]]["Eigth"],1)
            s_temp.repeatAppend(note_conversion_df.loc[third_measure.iloc[0]["Ki"]]["Eigth"],1)
            s_temp.repeatAppend(note_conversion_df.loc[third_measure.iloc[0]["ve2"]]["Eigth"],1)
                   
        
    # ilk Nota Quarter Es
    
    elif (measure_2_3=="Quarter"):
        
       #Third Measure _ _ x _  
    
        if (third_measure.iloc[0]["ve2"] == "nan"):           
            s_temp.repeatAppend(note_conversion_df.loc[third_measure.iloc[0]["Ki"]]["Quarter"],1)
         
        #Third Measure _ _ x x     
        else:
            s_temp.repeatAppend(note_conversion_df.loc[third_measure.iloc[0]["Ki"]]["Eigth"],1)
            s_temp.repeatAppend(note_conversion_df.loc[third_measure.iloc[0]["ve2"]]["Eigth"],1)
   
       
        
        
        
    s_temp = measure_conversion(melody.iloc[[3]], s_temp)  
    s_temp.repeatAppend(w_C, 1)
    s_temp.insert(0, meter.TimeSignature('4/4'))    
        
    return tie_score, s_temp

# %%
def write_score_es(melody):
    
    
    s_temp = stream.Stream()
    first_measure = melody.iloc[[0]]
    second_measure = melody.iloc[[1]]
    third_measure = melody.iloc[[2]]
    fourth_measure = melody.iloc[[3]]
    
    measure_1_2 = check_es(second_measure)
    measure_2_3 = check_es(third_measure)
    
  
    
    

    # First measure x _ _ _"
    
    if (first_measure.iloc[0]["ve"] == "nan") & (first_measure.iloc[0]["Ki"] == "nan") & (first_measure.iloc[0]["ve2"] == "nan"):
        note_add = note_conversion_df.loc[first_measure.iloc[0]["Bir"]]["Half"]
        if (measure_1_2=="nan"):
            s_temp.repeatAppend(note_add,1)
        elif (measure_1_2=="Eigth"):
            note_add = note_conversion_df.loc[first_measure.iloc[0]["Bir"]]["HalfEigthDot"]
            s_temp.repeatAppend(note_add,1)
        
            
        elif (measure_1_2=="Quarter"):
            note_add = note_conversion_df.loc[first_measure.iloc[0]["Bir"]]["HalfDot"]
            s_temp.repeatAppend(note_add,1)      
            
            
    # First measure x _ _ x
            
    elif (first_measure.iloc[0]["ve"] == "nan") & (first_measure.iloc[0]["Ki"] == "nan"):
        
        
        s_temp.repeatAppend(note_conversion_df.loc[first_measure.iloc[0]["Bir"]]["QuarterDot"],1)
        note_add = note_conversion_df.loc[first_measure.iloc[0]["ve2"]]["Eigth"]
        if (measure_1_2=="nan"):
            s_temp.repeatAppend(note_add,1)
        elif (measure_1_2=="Eigth"):
            note_add = note_conversion_df.loc[first_measure.iloc[0]["ve2"]]["Quarter"]
            s_temp.repeatAppend(note_add,1)
        elif (measure_1_2=="Quarter"):
            note_add = note_conversion_df.loc[first_measure.iloc[0]["ve2"]]["QuarterDot"]
            s_temp.repeatAppend(note_add,1)
                  

    # First measure x _ x _
    
    elif (first_measure.iloc[0]["ve"] == "nan") & (first_measure.iloc[0]["ve2"] == "nan"):
       
        s_temp.repeatAppend(note_conversion_df.loc[first_measure.iloc[0]["Bir"]]["Quarter"],1)
        note_add = note_conversion_df.loc[first_measure.iloc[0]["Ki"]]["Quarter"]
        if (measure_1_2=="nan"):
            s_temp.repeatAppend(note_add,1)
        elif (measure_1_2=="Eigth"):
            note_add = note_conversion_df.loc[first_measure.iloc[0]["Ki"]]["QuarterDot"]
            s_temp.repeatAppend(note_add,1)
        elif (measure_1_2=="Quarter"):
            note_add = note_conversion_df.loc[first_measure.iloc[0]["Ki"]]["HalfDot"]
            s_temp.repeatAppend(note_add,1)
            
    # First measure x _ x x   

    elif (first_measure.iloc[0]["ve"] == "nan"):
        
        s_temp.repeatAppend(note_conversion_df.loc[first_measure.iloc[0]["Bir"]]["Quarter"],1)
        s_temp.repeatAppend(note_conversion_df.loc[first_measure.iloc[0]["Ki"]]["Eigth"],1)
        note_add = note_conversion_df.loc[first_measure.iloc[0]["ve2"]]["Eigth"]
        if (measure_1_2=="nan"):
            s_temp.repeatAppend(note_add,1)
        elif (measure_1_2=="Eigth"):
            note_add = note_conversion_df.loc[first_measure.iloc[0]["ve2"]]["Quarter"]
            s_temp.repeatAppend(note_add,1)
        elif (measure_1_2=="Quarter"):
            note_add = note_conversion_df.loc[first_measure.iloc[0]["ve2"]]["QuarterDot"]
            s_temp.repeatAppend(note_add,1)
               
    
    # First measure x x _ _
    
    elif (first_measure.iloc[0]["Ki"] == "nan") & (first_measure.iloc[0]["ve2"] == "nan"):
        
        s_temp.repeatAppend(note_conversion_df.loc[first_measure.iloc[0]["Bir"]]["Eigth"],1)
        note_add = note_conversion_df.loc[first_measure.iloc[0]["ve"]]["QuarterDot"]
        if (measure_1_2=="nan"):
            s_temp.repeatAppend(note_add,1)
        elif (measure_1_2=="Eigth"):
            note_add = note_conversion_df.loc[first_measure.iloc[0]["ve"]]["Half"]
            s_temp.repeatAppend(note_add,1)       
        elif (measure_1_2=="Quarter"):
            note_add = note_conversion_df.loc[first_measure.iloc[0]["ve"]]["HalfEigthDot"]
            s_temp.repeatAppend(note_add,1)
            
    # First measure x x _ x        
            
    elif (first_measure.iloc[0]["Ki"] == "nan"):
       
        s_temp.repeatAppend(note_conversion_df.loc[first_measure.iloc[0]["Bir"]]["Eigth"],1)
        s_temp.repeatAppend(note_conversion_df.loc[first_measure.iloc[0]["ve"]]["Quarter"],1)
        note_add = note_conversion_df.loc[first_measure.iloc[0]["ve2"]]["Eigth"]
        if (measure_1_2=="nan"):
            s_temp.repeatAppend(note_add,1)
        elif (measure_1_2=="Eigth"):
            note_add = note_conversion_df.loc[first_measure.iloc[0]["ve2"]]["Quarter"]
            s_temp.repeatAppend(note_add,1)
        elif (measure_1_2=="Quarter"):
            note_add = note_conversion_df.loc[first_measure.iloc[0]["ve2"]]["QuarterDot"]
            s_temp.repeatAppend(note_add,1)
                 

    # First measure x x x _        
            
    elif (first_measure.iloc[0]["ve2"] == "nan"):           
       
        s_temp.repeatAppend(note_conversion_df.loc[first_measure.iloc[0]["Bir"]]["Eigth"],1)
        s_temp.repeatAppend(note_conversion_df.loc[first_measure.iloc[0]["ve"]]["Eigth"],1)
        note_add = note_conversion_df.loc[first_measure.iloc[0]["Ki"]]["Quarter"]
        if (measure_1_2=="nan"):
            s_temp.repeatAppend(note_add,1)
        elif (measure_1_2=="Eigth"):
            note_add = note_conversion_df.loc[first_measure.iloc[0]["Ki"]]["QuarterDot"]
            s_temp.repeatAppend(note_add,1)
        elif (measure_1_2=="Quarter"):
            note_add = note_conversion_df.loc[first_measure.iloc[0]["Ki"]]["Half"]
            s_temp.repeatAppend(note_add,1)
                

    # First measure x x x x
                
    else:
        
        s_temp.repeatAppend(note_conversion_df.loc[first_measure.iloc[0]["Bir"]]["Eigth"],1)
        s_temp.repeatAppend(note_conversion_df.loc[first_measure.iloc[0]["ve"]]["Eigth"],1)
        s_temp.repeatAppend(note_conversion_df.loc[first_measure.iloc[0]["Ki"]]["Eigth"],1)
        note_add = note_conversion_df.loc[first_measure.iloc[0]["ve2"]]["Eigth"]
        if (measure_1_2=="nan"):
            s_temp.repeatAppend(note_add,1)
        elif (measure_1_2=="Eigth"):
            note_add = note_conversion_df.loc[first_measure.iloc[0]["ve2"]]["Quarter"]
            s_temp.repeatAppend(note_add,1)
        elif (measure_1_2=="Quarter"):
            note_add = note_conversion_df.loc[first_measure.iloc[0]["ve2"]]["QuarterDot"]
            s_temp.repeatAppend(note_add,1)
    
                  

# 2nd Measure        


    # Seconda measure x _ _ _  

    if (measure_1_2=="nan"):
        if (second_measure.iloc[0]["ve"] == "nan") & (second_measure.iloc[0]["Ki"] == "nan") & (second_measure.iloc[0]["ve2"] == "nan"):
            note_add = note_conversion_df.loc[second_measure.iloc[0]["Bir"]]["Half"]
            if (measure_2_3=="nan"):
                s_temp.repeatAppend(note_add,1)
            elif (measure_2_3=="Eigth"):
                note_add = note_conversion_df.loc[second_measure.iloc[0]["Bir"]]["HalfEigthDot"]
                s_temp.repeatAppend(note_add,1)
            elif (measure_2_3=="Quarter"):
                note_add = note_conversion_df.loc[second_measure.iloc[0]["Bir"]]["HalfDot"]
                   
            
            
        # Seconda measure x _ _ x
            
        elif (second_measure.iloc[0]["ve"] == "nan") & (second_measure.iloc[0]["Ki"] == "nan"):
            
            s_temp.repeatAppend(note_conversion_df.loc[second_measure.iloc[0]["Bir"]]["QuarterDot"],1)
            note_add = note_conversion_df.loc[second_measure.iloc[0]["ve2"]]["Eigth"]
            if (measure_2_3=="nan"):
                s_temp.repeatAppend(note_add,1)
            elif (measure_2_3=="Eigth"):
                note_add = note_conversion_df.loc[second_measure.iloc[0]["ve2"]]["Quarter"]
                s_temp.repeatAppend(note_add,1)
            elif (measure_2_3=="Quarter"):
                note_add = note_conversion_df.loc[second_measure.iloc[0]["ve2"]]["QuarterDot"]
                s_temp.repeatAppend(note_add,1)
            
  
        # Seconda measure x _ x _
        
        elif (second_measure.iloc[0]["ve"] == "nan") & (second_measure.iloc[0]["ve2"] == "nan"):
            
            s_temp.repeatAppend(note_conversion_df.loc[second_measure.iloc[0]["Bir"]]["Quarter"],1)
            note_add = note_conversion_df.loc[second_measure.iloc[0]["Ki"]]["Quarter"]
            if (measure_2_3=="nan"):
                s_temp.repeatAppend(note_add,1)
            elif (measure_2_3=="Eigth"):
                note_add = note_conversion_df.loc[second_measure.iloc[0]["Ki"]]["QuarterDot"]
                s_temp.repeatAppend(note_add,1)
                
            elif (measure_2_3=="Quarter"):
                note_add = note_conversion_df.loc[second_measure.iloc[0]["Ki"]]["Half"]
                s_temp.repeatAppend(note_add,1)
                
        # Seconda measure x _ x x
        
        elif (second_measure.iloc[0]["ve"] == "nan"):
            
            s_temp.repeatAppend(note_conversion_df.loc[second_measure.iloc[0]["Bir"]]["Quarter"],1)
            s_temp.repeatAppend(note_conversion_df.loc[second_measure.iloc[0]["Ki"]]["Eigth"],1)
            note_add = note_conversion_df.loc[second_measure.iloc[0]["ve2"]]["Eigth"]
            if (measure_2_3=="nan"):
                s_temp.repeatAppend(note_add,1)
            elif (measure_2_3=="Eigth"):
                note_add = note_conversion_df.loc[second_measure.iloc[0]["ve2"]]["Quarter"]
                s_temp.repeatAppend(note_add,1)
                
            elif (measure_2_3=="Quarter"):
                note_add = note_conversion_df.loc[second_measure.iloc[0]["ve2"]]["QuarterDot"]
                s_temp.repeatAppend(note_add,1)
                 
        
        # Seconda measure x x _ _
        
        elif (second_measure.iloc[0]["Ki"] == "nan") & (second_measure.iloc[0]["ve2"] == "nan"):
           
            s_temp.repeatAppend(note_conversion_df.loc[second_measure.iloc[0]["Bir"]]["Eigth"],1)
            note_add = note_conversion_df.loc[second_measure.iloc[0]["ve"]]["QuarterDot"]
            if (measure_2_3=="nan"):
                s_temp.repeatAppend(note_add,1)
            elif (measure_2_3=="Eigth"):
                note_add = note_conversion_df.loc[second_measure.iloc[0]["ve"]]["Half"]
                s_temp.repeatAppend(note_add,1)
                
            elif (measure_2_3=="Quarter"):
                note_add = note_conversion_df.loc[second_measure.iloc[0]["ve"]]["HalfEigthDot"]
                s_temp.repeatAppend(note_add,1)
                   

         # Second measure x x _ x
        
        elif (second_measure.iloc[0]["Ki"] == "nan"):
            
            s_temp.repeatAppend(note_conversion_df.loc[second_measure.iloc[0]["Bir"]]["Eigth"],1)
            s_temp.repeatAppend(note_conversion_df.loc[second_measure.iloc[0]["ve"]]["Quarter"],1)
            note_add = note_conversion_df.loc[second_measure.iloc[0]["ve2"]]["Eigth"]
            if (measure_2_3=="nan"):
                s_temp.repeatAppend(note_add,1)
            elif (measure_2_3=="Eigth"):
                note_add = note_conversion_df.loc[second_measure.iloc[0]["ve2"]]["Quarter"]
                s_temp.repeatAppend(note_add,1)
                
            elif (measure_2_3=="Quarter"):
                note_add = note_conversion_df.loc[second_measure.iloc[0]["ve2"]]["QuarterDot"]
                s_temp.repeatAppend(note_add,1)
                
         # Second measure x x x _  
            
        elif (second_measure.iloc[0]["ve2"] == "nan"):           
            
            s_temp.repeatAppend(note_conversion_df.loc[second_measure.iloc[0]["Bir"]]["Eigth"],1)
            s_temp.repeatAppend(note_conversion_df.loc[second_measure.iloc[0]["ve"]]["Eigth"],1)
            note_add = note_conversion_df.loc[second_measure.iloc[0]["Ki"]]["Quarter"]
            if (measure_2_3=="nan"):
                s_temp.repeatAppend(note_add,1)
            elif (measure_2_3=="Eigth"):
                note_add = note_conversion_df.loc[second_measure.iloc[0]["Ki"]]["QuarterDot"]
                s_temp.repeatAppend(note_add,1)
               
            elif (measure_2_3=="Quarter"):
                note_add = note_conversion_df.loc[second_measure.iloc[0]["Ki"]]["Half"]
                s_temp.repeatAppend(note_add,1)
                 

        # Second measure x x x x 
        
        else:
            
            s_temp.repeatAppend(note_conversion_df.loc[second_measure.iloc[0]["Bir"]]["Eigth"],1)
            s_temp.repeatAppend(note_conversion_df.loc[second_measure.iloc[0]["ve"]]["Eigth"],1)
            s_temp.repeatAppend(note_conversion_df.loc[second_measure.iloc[0]["Ki"]]["Eigth"],1)
            note_add = note_conversion_df.loc[second_measure.iloc[0]["ve2"]]["Eigth"]
            if (measure_2_3=="nan"):
                s_temp.repeatAppend(note_add,1)
            elif (measure_2_3=="Eigth"):
                note_add = note_conversion_df.loc[second_measure.iloc[0]["ve2"]]["Quarter"]
                s_temp.repeatAppend(note_add,1)
               
            elif (measure_2_3=="Quarter"):
                note_add = note_conversion_df.loc[second_measure.iloc[0]["ve2"]]["QuarterDot"]
                s_temp.repeatAppend(note_add,1)
              

    # ilk Nota Eight Es
    
    elif (measure_1_2=="Eigth"):
        
       
        
        if (second_measure.iloc[0]["Ki"] == "nan") & (second_measure.iloc[0]["ve2"] == "nan"):
            note_add = note_conversion_df.loc[second_measure.iloc[0]["ve"]]["QuarterDot"]
            if (measure_2_3=="nan"):
                s_temp.repeatAppend(note_add,1)
            elif (measure_2_3=="Eigth"):
                note_add = note_conversion_df.loc[second_measure.iloc[0]["ve"]]["Half"]
                s_temp.repeatAppend(note_add,1)
            elif (measure_2_3=="Quarter"):
                note_add = note_conversion_df.loc[second_measure.iloc[0]["ve"]]["HalfEigthDot"]
                s_temp.repeatAppend(note_add,1)
                  

        #2nd measure _ x _ x 
        
        elif (second_measure.iloc[0]["Ki"] == "nan"):
           
            s_temp.repeatAppend(note_conversion_df.loc[second_measure.iloc[0]["ve"]]["Quarter"],1)
            note_add = note_conversion_df.loc[second_measure.iloc[0]["ve2"]]["Eigth"]
            if (measure_2_3=="nan"):
                s_temp.repeatAppend(note_add,1)
            elif (measure_2_3=="Eigth"):
                note_add = note_conversion_df.loc[second_measure.iloc[0]["ve2"]]["Quarter"]
                s_temp.repeatAppend(note_add,1)
                
            elif (measure_2_3=="Quarter"):
                note_add = note_conversion_df.loc[second_measure.iloc[0]["ve2"]]["QuarterDot"]
                s_temp.repeatAppend(note_add,1)
                
        #2nd measure _ x x _    
            
        elif (second_measure.iloc[0]["ve2"] == "nan"): 
            
            s_temp.repeatAppend(note_conversion_df.loc[second_measure.iloc[0]["ve"]]["Eigth"],1)
            note_add = note_conversion_df.loc[second_measure.iloc[0]["Ki"]]["Quarter"]
            if (measure_2_3=="nan"):
                s_temp.repeatAppend(note_add,1)
            elif (measure_2_3=="Eigth"):
                note_add = note_conversion_df.loc[second_measure.iloc[0]["Ki"]]["QuarterDot"]
                s_temp.repeatAppend(note_add,1)
            
            elif (measure_2_3=="Quarter"):
                note_add = note_conversion_df.loc[second_measure.iloc[0]["Ki"]]["Half"]
                s_temp.repeatAppend(note_add,1)
                   

        #2nd measure _ x x x        
            
        else:
            
            s_temp.repeatAppend(note_conversion_df.loc[second_measure.iloc[0]["ve"]]["Eigth"],1)
            s_temp.repeatAppend(note_conversion_df.loc[second_measure.iloc[0]["Ki"]]["Eigth"],1)
            note_add = note_conversion_df.loc[second_measure.iloc[0]["ve2"]]["Eigth"]
            if (measure_2_3=="nan"):
                s_temp.repeatAppend(note_add,1)
            elif (measure_2_3=="Eigth"):
                note_add = note_conversion_df.loc[second_measure.iloc[0]["ve2"]]["Quarter"]
                s_temp.repeatAppend(note_add,1)
                
            elif (measure_2_3=="Quarter"):
                note_add = note_conversion_df.loc[second_measure.iloc[0]["ve2"]]["QuarterDot"]
                s_temp.repeatAppend(note_add,1)
                
    # ilk Nota Quarter Es
    
    elif (measure_1_2=="Quarter"):
        
        #2nd measure _ _ x _ 
        
        if (second_measure.iloc[0]["ve2"] == "nan"):           
            note_add = note_conversion_df.loc[second_measure.iloc[0]["Ki"]]["Quarter"]
            if (measure_2_3=="nan"):
                s_temp.repeatAppend(note_add,1)
            elif (measure_2_3=="Eigth"):
                note_add = note_conversion_df.loc[second_measure.iloc[0]["Ki"]]["QuarterDot"]
                s_temp.repeatAppend(note_add,1)
                
            elif (measure_2_3=="Quarter"):
                note_add = note_conversion_df.loc[second_measure.iloc[0]["Ki"]]["Half"]
                s_temp.repeatAppend(note_add,1)
                
        #2nd measure _ _ x x        
            
        else:
          
            s_temp.repeatAppend(note_conversion_df.loc[second_measure.iloc[0]["Ki"]]["Eigth"],1)
            note_add = note_conversion_df.loc[second_measure.iloc[0]["ve2"]]["Eigth"]
            if (measure_2_3=="nan"):
                s_temp.repeatAppend(note_add,1)
            elif (measure_2_3=="Eigth"):
                note_add = note_conversion_df.loc[second_measure.iloc[0]["ve2"]]["Quarter"]
                s_temp.repeatAppend(note_add,1)
                
            elif (measure_2_3=="Quarter"):
                note_add = note_conversion_df.loc[second_measure.iloc[0]["ve2"]]["QuarterDot"]
                s_temp.repeatAppend(note_add,1)
                    
        
# 3rd measure

  
    #Third Measure x _ _ _  "
    
    if (measure_2_3=="nan"):
        if (third_measure.iloc[0]["ve"] == "nan") & (third_measure.iloc[0]["Ki"] == "nan") & (third_measure.iloc[0]["ve2"] == "nan"):
            note_add = note_conversion_df.loc[third_measure.iloc[0]["Bir"]]["Half"]
            s_temp.repeatAppend(note_add,1)
              
         #Third Measure x _ _ x   
        
        elif (third_measure.iloc[0]["ve"] == "nan") & (third_measure.iloc[0]["Ki"] == "nan"):
            
            s_temp.repeatAppend(note_conversion_df.loc[third_measure.iloc[0]["Bir"]]["QuarterDot"],1)
            note_add = note_conversion_df.loc[third_measure.iloc[0]["ve2"]]["Eigth"]
            s_temp.repeatAppend(note_add,1)
             
        #Third Measure x _ x _ 
            
        elif (third_measure.iloc[0]["ve"] == "nan") & (third_measure.iloc[0]["ve2"] == "nan"):
           
            s_temp.repeatAppend(note_conversion_df.loc[third_measure.iloc[0]["Bir"]]["Quarter"],1)
            note_add = note_conversion_df.loc[third_measure.iloc[0]["Ki"]]["Quarter"]
            s_temp.repeatAppend(note_add,1)
              
        #Third Measure x _ x x
        
        elif (third_measure.iloc[0]["ve"] == "nan"):
            
            s_temp.repeatAppend(note_conversion_df.loc[third_measure.iloc[0]["Bir"]]["Quarter"],1)
            s_temp.repeatAppend(note_conversion_df.loc[third_measure.iloc[0]["Ki"]]["Eigth"],1)
            note_add = note_conversion_df.loc[third_measure.iloc[0]["ve2"]]["Eigth"]
            s_temp.repeatAppend(note_add,1)
         
        #Third Measure x x _ _
            
        elif (third_measure.iloc[0]["Ki"] == "nan") & (third_measure.iloc[0]["ve2"] == "nan"):
            
            s_temp.repeatAppend(note_conversion_df.loc[third_measure.iloc[0]["Bir"]]["Eigth"],1)
            note_add = note_conversion_df.loc[third_measure.iloc[0]["ve"]]["QuarterDot"]
            s_temp.repeatAppend(note_add,1)
            
        #Third Measure x x _ x
        
        elif (third_measure.iloc[0]["Ki"] == "nan"):
            
            s_temp.repeatAppend(note_conversion_df.loc[third_measure.iloc[0]["Bir"]]["Eigth"],1)
            s_temp.repeatAppend(note_conversion_df.loc[third_measure.iloc[0]["ve"]]["Quarter"],1)
            note_add = note_conversion_df.loc[third_measure.iloc[0]["ve2"]]["Eigth"]
            s_temp.repeatAppend(note_add,1)
            
        #Third Measure x x x -   
            
        elif (third_measure.iloc[0]["ve2"] == "nan"):           
            
            s_temp.repeatAppend(note_conversion_df.loc[third_measure.iloc[0]["Bir"]]["Eigth"],1)
            s_temp.repeatAppend(note_conversion_df.loc[third_measure.iloc[0]["ve"]]["Eigth"],1)
            note_add = note_conversion_df.loc[third_measure.iloc[0]["Ki"]]["Quarter"]
            s_temp.repeatAppend(note_add,1)
        
        #Third Measure x x x x 
        else:
           
            s_temp.repeatAppend(note_conversion_df.loc[third_measure.iloc[0]["Bir"]]["Eigth"],1)
            s_temp.repeatAppend(note_conversion_df.loc[third_measure.iloc[0]["ve"]]["Eigth"],1)
            s_temp.repeatAppend(note_conversion_df.loc[third_measure.iloc[0]["Ki"]]["Eigth"],1)
            s_temp.repeatAppend(note_conversion_df.loc[third_measure.iloc[0]["ve2"]]["Eigth"],1)
          
            
    # ilk Nota Eight Es
    
    elif (measure_2_3=="Eigth"):
        
          
        
        if (third_measure.iloc[0]["Ki"] == "nan") & (third_measure.iloc[0]["ve2"] == "nan"):
            s_temp.repeatAppend(note_conversion_df.loc[third_measure.iloc[0]["ve"]]["QuarterDot"],1)
          
         
        #Third Measure _ x _ x  
            
        elif (third_measure.iloc[0]["Ki"] == "nan"):
            
            s_temp.repeatAppend(note_conversion_df.loc[third_measure.iloc[0]["ve"]]["Quarter"],1)
            s_temp.repeatAppend(note_conversion_df.loc[second_measure.iloc[0]["ve2"]]["Eigth"],1)
             

        #Third Measure _ x x _      
            
        elif (third_measure.iloc[0]["ve2"] == "nan"): 
            
            s_temp.repeatAppend(note_conversion_df.loc[third_measure.iloc[0]["ve"]]["Eigth"],1)
            s_temp.repeatAppend(note_conversion_df.loc[third_measure.iloc[0]["Ki"]]["Quarter"],1)
                         
        #Third Measure _ x x x  
            
        else:
            
            s_temp.repeatAppend(note_conversion_df.loc[third_measure.iloc[0]["ve"]]["Eigth"],1)
            s_temp.repeatAppend(note_conversion_df.loc[third_measure.iloc[0]["Ki"]]["Eigth"],1)
            s_temp.repeatAppend(note_conversion_df.loc[third_measure.iloc[0]["ve2"]]["Eigth"],1)
                   
        
    # ilk Nota Quarter Es
    
    elif (measure_2_3=="Quarter"):
        
         
    
        if (third_measure.iloc[0]["ve2"] == "nan"):           
            s_temp.repeatAppend(note_conversion_df.loc[third_measure.iloc[0]["Ki"]]["Quarter"],1)
         
        #Third Measure _ _ x x     
        else:
            #print("#Third Measure _ _ x x  ")
            s_temp.repeatAppend(note_conversion_df.loc[third_measure.iloc[0]["Ki"]]["Eigth"],1)
            s_temp.repeatAppend(note_conversion_df.loc[third_measure.iloc[0]["ve2"]]["Eigth"],1)
   
       
        
        
        
    s_temp = measure_conversion(melody.iloc[[3]], s_temp)  
    
    
    #s_temp.repeatAppend(note_conversion_df.loc[fourth_measure.iloc[0]["Bir"]]["Quarter"], 1)
    #s_temp.repeatAppend(note_conversion_df.loc[fourth_measure.iloc[0]["Ki"]]["Eigth"], 1)
    #s_temp.repeatAppend(note_conversion_df.loc[fourth_measure.iloc[0]["ve2"]]["Eigth"], 1)
    
    
    s_temp.repeatAppend(w_C, 1)
    s_temp.insert(0, meter.TimeSignature('4/4'))    
        
    return s_temp

# %%
#selected_chord_prog = random.randint(1, 6)
selected_chord_prog = 1
print(type(selected_chord_prog))
my_prog = chord_progression.iloc[[selected_chord_prog-1]]
my_prog
# Out:
# <class 'int'>
#   Start Continuation1 Continuation2 Cadence1 Cadence2
# 1     I             V             I        V        I

# %%
def write_score_no_tie(melody):
    
    
    s_temp = stream.Stream()
    first_measure = melody.iloc[[0]]
    second_measure = melody.iloc[[1]]
    third_measure = melody.iloc[[2]]
    
    measure_1_2 = check_es(second_measure)
    measure_2_3 = check_es(third_measure)
    

    # First measure x _ _ _
    
    if (first_measure.iloc[0]["ve"] == "nan") & (first_measure.iloc[0]["Ki"] == "nan") & (first_measure.iloc[0]["ve2"] == "nan"):
        note_add = note_conversion_df.loc[first_measure.iloc[0]["Bir"]]["Half"]
        if (measure_1_2=="nan"):
            s_temp.repeatAppend(note_add,1)
        elif (measure_1_2=="Eigth"):
            s_temp.repeatAppend(note_add,1)
            note_add = note_conversion_df.loc[first_measure.iloc[0]["Bir"]]["Eigth"]
            s_temp.repeatAppend(note_add,1)
        elif (measure_1_2=="Quarter"):
            
            
            s_temp.repeatAppend(note_add,1)
            note_add = note_conversion_df.loc[first_measure.iloc[0]["Bir"]]["Quarter"]
            
            s_temp.repeatAppend(note_add,1)      
            
            
    # First measure x _ _ x
            
    elif (first_measure.iloc[0]["ve"] == "nan") & (first_measure.iloc[0]["Ki"] == "nan"):
        s_temp.repeatAppend(note_conversion_df.loc[first_measure.iloc[0]["Bir"]]["QuarterDot"],1)
        note_add = note_conversion_df.loc[first_measure.iloc[0]["ve2"]]["Eigth"]
        if (measure_1_2=="nan"):
            s_temp.repeatAppend(note_add,1)
        elif (measure_1_2=="Eigth"):
            
            
            s_temp.repeatAppend(note_add,1)
            note_add = note_conversion_df.loc[first_measure.iloc[0]["ve2"]]["Eigth"]
            s_temp.repeatAppend(note_add,1)
        elif (measure_1_2=="Quarter"):
            
            s_temp.repeatAppend(note_add,1)
            note_add = note_conversion_df.loc[first_measure.iloc[0]["ve2"]]["Quarter"]
            s_temp.repeatAppend(note_add,1)      

    # First measure x _ x _
    
    elif (first_measure.iloc[0]["ve"] == "nan") & (first_measure.iloc[0]["ve2"] == "nan"):
        s_temp.repeatAppend(note_conversion_df.loc[first_measure.iloc[0]["Bir"]]["Quarter"],1)
        note_add = note_conversion_df.loc[first_measure.iloc[0]["Ki"]]["Quarter"]
        if (measure_1_2=="nan"):
            s_temp.repeatAppend(note_add,1)
        elif (measure_1_2=="Eigth"):
            
            s_temp.repeatAppend(note_add,1)
            note_add = note_conversion_df.loc[first_measure.iloc[0]["Ki"]]["Eigth"]
            s_temp.repeatAppend(note_add,1)
        elif (measure_1_2=="Quarter"):
            
            s_temp.repeatAppend(note_add,1)
            note_add = note_conversion_df.loc[first_measure.iloc[0]["Ki"]]["Quarter"]
            s_temp.repeatAppend(note_add,1)      
        
    # First measure x _ x x   

    elif (first_measure.iloc[0]["ve"] == "nan"):
        s_temp.repeatAppend(note_conversion_df.loc[first_measure.iloc[0]["Bir"]]["Quarter"],1)
        s_temp.repeatAppend(note_conversion_df.loc[first_measure.iloc[0]["Ki"]]["Eigth"],1)
        note_add = note_conversion_df.loc[first_measure.iloc[0]["ve2"]]["Eigth"]
        if (measure_1_2=="nan"):
            s_temp.repeatAppend(note_add,1)
        elif (measure_1_2=="Eigth"):
            
            s_temp.repeatAppend(note_add,1)
            note_add = note_conversion_df.loc[first_measure.iloc[0]["ve2"]]["Eigth"]
            s_temp.repeatAppend(note_add,1)
        elif (measure_1_2=="Quarter"):
            
            s_temp.repeatAppend(note_add,1)
            note_add = note_conversion_df.loc[first_measure.iloc[0]["ve2"]]["Quarter"]
            s_temp.repeatAppend(note_add,1)   
    
    # First measure x x _ _
    
    elif (first_measure.iloc[0]["Ki"] == "nan") & (first_measure.iloc[0]["ve2"] == "nan"):
        s_temp.repeatAppend(note_conversion_df.loc[first_measure.iloc[0]["Bir"]]["Eigth"],1)
        note_add = note_conversion_df.loc[first_measure.iloc[0]["ve"]]["QuarterDot"]
        if (measure_1_2=="nan"):
            s_temp.repeatAppend(note_add,1)
        elif (measure_1_2=="Eigth"):
            
            s_temp.repeatAppend(note_add,1)
            note_add = note_conversion_df.loc[first_measure.iloc[0]["ve"]]["Eigth"]
            s_temp.repeatAppend(note_add,1)
        elif (measure_1_2=="Quarter"):
            
            s_temp.repeatAppend(note_add,1)
            note_add = note_conversion_df.loc[first_measure.iloc[0]["ve"]]["Quarter"]
            s_temp.repeatAppend(note_add,1)      

    # First measure x x _ x        
            
    elif (first_measure.iloc[0]["Ki"] == "nan"):
        s_temp.repeatAppend(note_conversion_df.loc[first_measure.iloc[0]["Bir"]]["Eigth"],1)
        s_temp.repeatAppend(note_conversion_df.loc[first_measure.iloc[0]["ve"]]["Quarter"],1)
        note_add = note_conversion_df.loc[first_measure.iloc[0]["ve2"]]["Eigth"]
        if (measure_1_2=="nan"):
            s_temp.repeatAppend(note_add,1)
        elif (measure_1_2=="Eigth"):
            
            s_temp.repeatAppend(note_add,1)
            note_add = note_conversion_df.loc[first_measure.iloc[0]["ve2"]]["Eigth"]
            s_temp.repeatAppend(note_add,1)
        elif (measure_1_2=="Quarter"):
            
            s_temp.repeatAppend(note_add,1)
            note_add = note_conversion_df.loc[first_measure.iloc[0]["ve2"]]["Quarter"]
            s_temp.repeatAppend(note_add,1)      

    # First measure x x x _        
            
    elif (first_measure.iloc[0]["ve2"] == "nan"):           
        s_temp.repeatAppend(note_conversion_df.loc[first_measure.iloc[0]["Bir"]]["Eigth"],1)
        s_temp.repeatAppend(note_conversion_df.loc[first_measure.iloc[0]["ve"]]["Eigth"],1)
        note_add = note_conversion_df.loc[first_measure.iloc[0]["Ki"]]["Quarter"]
        if (measure_1_2=="nan"):
            s_temp.repeatAppend(note_add,1)
        elif (measure_1_2=="Eigth"):
            
            s_temp.repeatAppend(note_add,1)
            note_add = note_conversion_df.loc[first_measure.iloc[0]["Ki"]]["Eigth"]
            s_temp.repeatAppend(note_add,1)
        elif (measure_1_2=="Quarter"):
            
            s_temp.repeatAppend(note_add,1)
            note_add = note_conversion_df.loc[first_measure.iloc[0]["Ki"]]["Quarter"]
            s_temp.repeatAppend(note_add,1)      

    # First measure x x x x
                
    else:
        s_temp.repeatAppend(note_conversion_df.loc[first_measure.iloc[0]["Bir"]]["Eigth"],1)
        s_temp.repeatAppend(note_conversion_df.loc[first_measure.iloc[0]["ve"]]["Eigth"],1)
        s_temp.repeatAppend(note_conversion_df.loc[first_measure.iloc[0]["Ki"]]["Eigth"],1)
        note_add = note_conversion_df.loc[first_measure.iloc[0]["ve2"]]["Eigth"]
        if (measure_1_2=="nan"):
            s_temp.repeatAppend(note_add,1)
        elif (measure_1_2=="Eigth"):
           
            s_temp.repeatAppend(note_add,1)
            note_add = note_conversion_df.loc[first_measure.iloc[0]["ve2"]]["Eigth"]
            s_temp.repeatAppend(note_add,1)
        elif (measure_1_2=="Quarter"):
            
            s_temp.repeatAppend(note_add,1)
            note_add = note_conversion_df.loc[first_measure.iloc[0]["ve2"]]["Quarter"]
            s_temp.repeatAppend(note_add,1)      

# 2nd Measure        


    # Seconda measure x _ _ _   

    if (measure_1_2=="nan"):
        if (second_measure.iloc[0]["ve"] == "nan") & (second_measure.iloc[0]["Ki"] == "nan") & (second_measure.iloc[0]["ve2"] == "nan"):
            note_add = note_conversion_df.loc[second_measure.iloc[0]["Bir"]]["Half"]
            if (measure_2_3=="nan"):
                s_temp.repeatAppend(note_add,1)
            elif (measure_2_3=="Eigth"):
                
                s_temp.repeatAppend(note_add,1)
                note_add = note_conversion_df.loc[second_measure.iloc[0]["Bir"]]["Eigth"]
                s_temp.repeatAppend(note_add,1)
            elif (measure_2_3=="Quarter"):
                
                s_temp.repeatAppend(note_add,1)
                note_add = note_conversion_df.loc[second_measure.iloc[0]["Bir"]]["Quarter"]
                s_temp.repeatAppend(note_add,1)      
            
            
        # Seconda measure x _ _ x
            
        elif (second_measure.iloc[0]["ve"] == "nan") & (second_measure.iloc[0]["Ki"] == "nan"):
            s_temp.repeatAppend(note_conversion_df.loc[second_measure.iloc[0]["Bir"]]["QuarterDot"],1)
            note_add = note_conversion_df.loc[second_measure.iloc[0]["ve2"]]["Eigth"]
            if (measure_2_3=="nan"):
                s_temp.repeatAppend(note_add,1)
            elif (measure_2_3=="Eigth"):
                
                s_temp.repeatAppend(note_add,1)
                note_add = note_conversion_df.loc[second_measure.iloc[0]["ve2"]]["Eigth"]
                s_temp.repeatAppend(note_add,1)
            elif (measure_2_3=="Quarter"):
                
                s_temp.repeatAppend(note_add,1)
                note_add = note_conversion_df.loc[second_measure.iloc[0]["ve2"]]["Quarter"]
                s_temp.repeatAppend(note_add,1)      

        
        # Seconda measure x _ x _
        
        elif (second_measure.iloc[0]["ve"] == "nan") & (second_measure.iloc[0]["ve2"] == "nan"):
            s_temp.repeatAppend(note_conversion_df.loc[second_measure.iloc[0]["Bir"]]["Quarter"],1)
            note_add = note_conversion_df.loc[second_measure.iloc[0]["Ki"]]["Quarter"]
            if (measure_2_3=="nan"):
                s_temp.repeatAppend(note_add,1)
            elif (measure_2_3=="Eigth"):
                
                s_temp.repeatAppend(note_add,1)
                note_add = note_conversion_df.loc[second_measure.iloc[0]["Ki"]]["Eigth"]
                s_temp.repeatAppend(note_add,1)
            elif (measure_2_3=="Quarter"):
               
                s_temp.repeatAppend(note_add,1)
                note_add = note_conversion_df.loc[second_measure.iloc[0]["Ki"]]["Quarter"]
                s_temp.repeatAppend(note_add,1)      
        
        # Seconda measure x _ x x
        
        elif (second_measure.iloc[0]["ve"] == "nan"):
            s_temp.repeatAppend(note_conversion_df.loc[second_measure.iloc[0]["Bir"]]["Quarter"],1)
            s_temp.repeatAppend(note_conversion_df.loc[second_measure.iloc[0]["Ki"]]["Eigth"],1)
            note_add = note_conversion_df.loc[second_measure.iloc[0]["ve2"]]["Eigth"]
            if (measure_2_3=="nan"):
                s_temp.repeatAppend(note_add,1)
            elif (measure_2_3=="Eigth"):
               
                s_temp.repeatAppend(note_add,1)
                note_add = note_conversion_df.loc[second_measure.iloc[0]["ve2"]]["Eigth"]
                s_temp.repeatAppend(note_add,1)
            elif (measure_2_3=="Quarter"):
                
                s_temp.repeatAppend(note_add,1)
                note_add = note_conversion_df.loc[second_measure.iloc[0]["ve2"]]["Quarter"]
                s_temp.repeatAppend(note_add,1)   
        
        # Seconda measure x x _ _
        
        elif (second_measure.iloc[0]["Ki"] == "nan") & (second_measure.iloc[0]["ve2"] == "nan"):
            s_temp.repeatAppend(note_conversion_df.loc[second_measure.iloc[0]["Bir"]]["Eigth"],1)
            note_add = note_conversion_df.loc[second_measure.iloc[0]["ve"]]["QuarterDot"]
            if (measure_2_3=="nan"):
                s_temp.repeatAppend(note_add,1)
            elif (measure_2_3=="Eigth"):
               
                s_temp.repeatAppend(note_add,1)
                note_add = note_conversion_df.loc[second_measure.iloc[0]["ve"]]["Eigth"]
                s_temp.repeatAppend(note_add,1)
            elif (measure_2_3=="Quarter"):
                
                s_temp.repeatAppend(note_add,1)
                note_add = note_conversion_df.loc[second_measure.iloc[0]["ve"]]["Quarter"]
                s_temp.repeatAppend(note_add,1)      

         # Second measure x x _ x
        
        elif (second_measure.iloc[0]["Ki"] == "nan"):
            s_temp.repeatAppend(note_conversion_df.loc[second_measure.iloc[0]["Bir"]]["Eigth"],1)
            s_temp.repeatAppend(note_conversion_df.loc[second_measure.iloc[0]["ve"]]["Quarter"],1)
            note_add = note_conversion_df.loc[second_measure.iloc[0]["ve2"]]["Eigth"]
            if (measure_2_3=="nan"):
                s_temp.repeatAppend(note_add,1)
            elif (measure_2_3=="Eigth"):
                
                s_temp.repeatAppend(note_add,1)
                note_add = note_conversion_df.loc[second_measure.iloc[0]["ve2"]]["Eigth"]
                s_temp.repeatAppend(note_add,1)
            elif (measure_2_3=="Quarter"):
                
                s_temp.repeatAppend(note_add,1)
                note_add = note_conversion_df.loc[second_measure.iloc[0]["ve2"]]["Quarter"]
                s_temp.repeatAppend(note_add,1)      

         # Second measure x x x _  
            
        elif (second_measure.iloc[0]["ve2"] == "nan"):           
            s_temp.repeatAppend(note_conversion_df.loc[second_measure.iloc[0]["Bir"]]["Eigth"],1)
            s_temp.repeatAppend(note_conversion_df.loc[second_measure.iloc[0]["ve"]]["Eigth"],1)
            note_add = note_conversion_df.loc[second_measure.iloc[0]["Ki"]]["Quarter"]
            if (measure_2_3=="nan"):
                s_temp.repeatAppend(note_add,1)
            elif (measure_2_3=="Eigth"):
                
                s_temp.repeatAppend(note_add,1)
                note_add = note_conversion_df.loc[second_measure.iloc[0]["Ki"]]["Eigth"]
                s_temp.repeatAppend(note_add,1)
            elif (measure_2_3=="Quarter"):
                
                s_temp.repeatAppend(note_add,1)
                note_add = note_conversion_df.loc[second_measure.iloc[0]["Ki"]]["Quarter"]
                s_temp.repeatAppend(note_add,1)      

        # Second measure x x x x 
        
        else:
            s_temp.repeatAppend(note_conversion_df.loc[second_measure.iloc[0]["Bir"]]["Eigth"],1)
            s_temp.repeatAppend(note_conversion_df.loc[second_measure.iloc[0]["ve"]]["Eigth"],1)
            s_temp.repeatAppend(note_conversion_df.loc[second_measure.iloc[0]["Ki"]]["Eigth"],1)
            note_add = note_conversion_df.loc[second_measure.iloc[0]["ve2"]]["Eigth"]
            if (measure_2_3=="nan"):
                s_temp.repeatAppend(note_add,1)
            elif (measure_2_3=="Eigth"):
                
                s_temp.repeatAppend(note_add,1)
                note_add = note_conversion_df.loc[second_measure.iloc[0]["ve2"]]["Eigth"]
                s_temp.repeatAppend(note_add,1)
            elif (measure_2_3=="Quarter"):
                
                s_temp.repeatAppend(note_add,1)
                note_add = note_conversion_df.loc[second_measure.iloc[0]["ve2"]]["Quarter"]
                s_temp.repeatAppend(note_add,1)      

    # ilk Nota Eight Es
    
    elif (measure_1_2=="Eigth"):
        
        #2nd measure _ x _ _
        
        if (second_measure.iloc[0]["Ki"] == "nan") & (second_measure.iloc[0]["ve2"] == "nan"):
            note_add = note_conversion_df.loc[second_measure.iloc[0]["ve"]]["QuarterDot"]
            if (measure_2_3=="nan"):
                s_temp.repeatAppend(note_add,1)
            elif (measure_2_3=="Eigth"):
                
                s_temp.repeatAppend(note_add,1)
                note_add = note_conversion_df.loc[second_measure.iloc[0]["ve"]]["Eigth"]
                s_temp.repeatAppend(note_add,1)
            elif (measure_2_3=="Quarter"):
                
                s_temp.repeatAppend(note_add,1)
                note_add = note_conversion_df.loc[second_measure.iloc[0]["ve"]]["Quarter"]
                s_temp.repeatAppend(note_add,1)      

        #2nd measure _ x _ x 
        
        elif (second_measure.iloc[0]["Ki"] == "nan"):
            s_temp.repeatAppend(note_conversion_df.loc[second_measure.iloc[0]["ve"]]["Quarter"],1)
            note_add = note_conversion_df.loc[second_measure.iloc[0]["ve2"]]["Eigth"]
            if (measure_2_3=="nan"):
                s_temp.repeatAppend(note_add,1)
            elif (measure_2_3=="Eigth"):
                
                s_temp.repeatAppend(note_add,1)
                note_add = note_conversion_df.loc[second_measure.iloc[0]["ve2"]]["Eigth"]
                s_temp.repeatAppend(note_add,1)
            elif (measure_2_3=="Quarter"):
                
                s_temp.repeatAppend(note_add,1)
                note_add = note_conversion_df.loc[second_measure.iloc[0]["ve2"]]["Quarter"]
                s_temp.repeatAppend(note_add,1)      

        #2nd measure _ x x _    
            
        elif (second_measure.iloc[0]["ve2"] == "nan"):           
            s_temp.repeatAppend(note_conversion_df.loc[second_measure.iloc[0]["ve"]]["Eigth"],1)
            note_add = note_conversion_df.loc[second_measure.iloc[0]["Ki"]]["Quarter"]
            if (measure_2_3=="nan"):
                s_temp.repeatAppend(note_add,1)
            elif (measure_2_3=="Eigth"):
                
                s_temp.repeatAppend(note_add,1)
                note_add = note_conversion_df.loc[second_measure.iloc[0]["Ki"]]["Eigth"]
                s_temp.repeatAppend(note_add,1)
            elif (measure_2_3=="Quarter"):
                
                s_temp.repeatAppend(note_add,1)
                note_add = note_conversion_df.loc[second_measure.iloc[0]["Ki"]]["Quarter"]
                s_temp.repeatAppend(note_add,1)      

        #2nd measure _ x x x        
            
        else:
            s_temp.repeatAppend(note_conversion_df.loc[second_measure.iloc[0]["ve"]]["Eigth"],1)
            s_temp.repeatAppend(note_conversion_df.loc[second_measure.iloc[0]["Ki"]]["Eigth"],1)
            note_add = note_conversion_df.loc[second_measure.iloc[0]["ve2"]]["Eigth"]
            if (measure_2_3=="nan"):
                s_temp.repeatAppend(note_add,1)
            elif (measure_2_3=="Eigth"):
                
                s_temp.repeatAppend(note_add,1)
                note_add = note_conversion_df.loc[second_measure.iloc[0]["ve2"]]["Eigth"]
                s_temp.repeatAppend(note_add,1)
            elif (measure_2_3=="Quarter"):
                
                s_temp.repeatAppend(note_add,1)
                note_add = note_conversion_df.loc[second_measure.iloc[0]["ve2"]]["Quarter"]
                s_temp.repeatAppend(note_add,1)      
        
    # ilk Nota Quarter Es
    
    elif (measure_1_2=="Quarter"):
        
        #2nd measure _ _ x _ 
        
        if (second_measure.iloc[0]["ve2"] == "nan"):           
            note_add = note_conversion_df.loc[second_measure.iloc[0]["Ki"]]["Quarter"]
            if (measure_2_3=="nan"):
                s_temp.repeatAppend(note_add,1)
            elif (measure_2_3=="Eigth"):
                
                s_temp.repeatAppend(note_add,1)
                note_add = note_conversion_df.loc[second_measure.iloc[0]["Ki"]]["Eigth"]
                s_temp.repeatAppend(note_add,1)
            elif (measure_2_3=="Quarter"):
                
                s_temp.repeatAppend(note_add,1)
                note_add = note_conversion_df.loc[second_measure.iloc[0]["Ki"]]["Quarter"]
                s_temp.repeatAppend(note_add,1)      

        #2nd measure _ _ x x        
            
        else:
           
            s_temp.repeatAppend(note_conversion_df.loc[second_measure.iloc[0]["Ki"]]["Eigth"],1)
            #note_add.tie = tie.Tie("stop")
            note_add = note_conversion_df.loc[second_measure.iloc[0]["ve2"]]["Eigth"]
            #note_add.tie = tie.Tie("stop")
            if (measure_2_3=="nan"):
                s_temp.repeatAppend(note_add,1)
            elif (measure_2_3=="Eigth"):
                
                s_temp.repeatAppend(note_add,1)
                note_add = note_conversion_df.loc[second_measure.iloc[0]["ve2"]]["Eigth"]
                s_temp.repeatAppend(note_add,1)
                
            elif (measure_2_3=="Quarter"):
                
                s_temp.repeatAppend(note_add,1)
                note_add = note_conversion_df.loc[second_measure.iloc[0]["ve2"]]["Quarter"]
                s_temp.repeatAppend(note_add,1)
                
        
# 3rd measure

  
    #Third Measure x _ _ _  
    
    if (measure_2_3=="nan"):
        if (third_measure.iloc[0]["ve"] == "nan") & (third_measure.iloc[0]["Ki"] == "nan") & (third_measure.iloc[0]["ve2"] == "nan"):
            note_add = note_conversion_df.loc[third_measure.iloc[0]["Bir"]]["Half"]
            s_temp.repeatAppend(note_add,1)
              
         #Third Measure x _ _ x   
        
        elif (third_measure.iloc[0]["ve"] == "nan") & (third_measure.iloc[0]["Ki"] == "nan"):
            s_temp.repeatAppend(note_conversion_df.loc[third_measure.iloc[0]["Bir"]]["QuarterDot"],1)
            note_add = note_conversion_df.loc[third_measure.iloc[0]["ve2"]]["Eigth"]
            s_temp.repeatAppend(note_add,1)
             
        #Third Measure x _ x _ 
            
        elif (third_measure.iloc[0]["ve"] == "nan") & (third_measure.iloc[0]["ve2"] == "nan"):
            s_temp.repeatAppend(note_conversion_df.loc[third_measure.iloc[0]["Bir"]]["Quarter"],1)
            note_add = note_conversion_df.loc[third_measure.iloc[0]["Ki"]]["Quarter"]
            s_temp.repeatAppend(note_add,1)
              
        #Third Measure x _ x x
        
        elif (third_measure.iloc[0]["ve"] == "nan"):
            s_temp.repeatAppend(note_conversion_df.loc[third_measure.iloc[0]["Bir"]]["Quarter"],1)
            s_temp.repeatAppend(note_conversion_df.loc[third_measure.iloc[0]["Ki"]]["Eigth"],1)
            note_add = note_conversion_df.loc[third_measure.iloc[0]["ve2"]]["Eigth"]
            s_temp.repeatAppend(note_add,1)
         
        #Third Measure x x _ _
            
        elif (third_measure.iloc[0]["Ki"] == "nan") & (third_measure.iloc[0]["ve2"] == "nan"):
            s_temp.repeatAppend(note_conversion_df.loc[third_measure.iloc[0]["Bir"]]["Eigth"],1)
            note_add = note_conversion_df.loc[third_measure.iloc[0]["ve"]]["QuarterDot"]
            s_temp.repeatAppend(note_add,1)
            
        #Third Measure x x _ x
        
        elif (third_measure.iloc[0]["Ki"] == "nan"):
            s_temp.repeatAppend(note_conversion_df.loc[third_measure.iloc[0]["Bir"]]["Eigth"],1)
            s_temp.repeatAppend(note_conversion_df.loc[third_measure.iloc[0]["ve"]]["Quarter"],1)
            note_add = note_conversion_df.loc[third_measure.iloc[0]["ve2"]]["Eigth"]
            s_temp.repeatAppend(note_add,1)
            
        #Third Measure x x x -   
            
        elif (third_measure.iloc[0]["ve2"] == "nan"):           
            s_temp.repeatAppend(note_conversion_df.loc[third_measure.iloc[0]["Bir"]]["Eigth"],1)
            s_temp.repeatAppend(note_conversion_df.loc[third_measure.iloc[0]["ve"]]["Eigth"],1)
            note_add = note_conversion_df.loc[third_measure.iloc[0]["Ki"]]["Quarter"]
            s_temp.repeatAppend(note_add,1)
        
        #Third Measure x x x x 
        else:
            s_temp.repeatAppend(note_conversion_df.loc[third_measure.iloc[0]["Bir"]]["Eigth"],1)
            s_temp.repeatAppend(note_conversion_df.loc[third_measure.iloc[0]["ve"]]["Eigth"],1)
            s_temp.repeatAppend(note_conversion_df.loc[third_measure.iloc[0]["Ki"]]["Eigth"],1)
            s_temp.repeatAppend(note_conversion_df.loc[third_measure.iloc[0]["ve2"]]["Eigth"],1)
          
            
    # ilk Nota Eight Es
    
    elif (measure_2_3=="Eigth"):
        
        #Third Measure _ x _ _  
        
        if (third_measure.iloc[0]["Ki"] == "nan") & (third_measure.iloc[0]["ve2"] == "nan"):
            s_temp.repeatAppend(note_conversion_df.loc[third_measure.iloc[0]["ve"]]["QuarterDot"],1)
          
         
        #Third Measure _ x _ x  
            
        elif (third_measure.iloc[0]["Ki"] == "nan"):
            s_temp.repeatAppend(note_conversion_df.loc[third_measure.iloc[0]["ve"]]["Quarter"],1)
            s_temp.repeatAppend(note_conversion_df.loc[second_measure.iloc[0]["ve2"]]["Eigth"],1)
             

        #Third Measure _ x x _      
            
        elif (third_measure.iloc[0]["ve2"] == "nan"):           
            s_temp.repeatAppend(note_conversion_df.loc[third_measure.iloc[0]["ve"]]["Eigth"],1)
            s_temp.repeatAppend(note_conversion_df.loc[third_measure.iloc[0]["Ki"]]["Quarter"],1)
                         
        #Third Measure _ x x x  
            
        else:
            s_temp.repeatAppend(note_conversion_df.loc[third_measure.iloc[0]["ve"]]["Eigth"],1)
            s_temp.repeatAppend(note_conversion_df.loc[third_measure.iloc[0]["Ki"]]["Eigth"],1)
            s_temp.repeatAppend(note_conversion_df.loc[third_measure.iloc[0]["ve2"]]["Eigth"],1)
                   
        
    # ilk Nota Quarter Es
    
    elif (measure_2_3=="Quarter"):
        
       #Third Measure _ _ x _  
    
        if (third_measure.iloc[0]["ve2"] == "nan"):           
            s_temp.repeatAppend(note_conversion_df.loc[third_measure.iloc[0]["Ki"]]["Quarter"],1)
         
        #Third Measure _ _ x x     
        else:
            s_temp.repeatAppend(note_conversion_df.loc[third_measure.iloc[0]["Ki"]]["Eigth"],1)
            s_temp.repeatAppend(note_conversion_df.loc[third_measure.iloc[0]["ve2"]]["Eigth"],1)
   
       
        
        
        
    s_temp = measure_conversion(melody.iloc[[3]], s_temp)  
    s_temp.repeatAppend(w_C, 1)
    s_temp.insert(0, meter.TimeSignature('4/4'))    
        
    return s_temp

# %%
melodies_no_tie = []
melodies_with_tie = []


with_tie_count = 0
no_tie_count = 0


selected_chord_prog = 6
print("Chord Progression: ", selected_chord_prog)
my_prog = chord_progression.iloc[[selected_chord_prog-1]]
my_prog
melody_count = 0

for melody_count in range(25):
    print("________________________________")
    print("Melody Count is: ", melody_count)
    tie_yes_no = False
    Q = 8
    Rep = 10
    leap_step_ratio = 1.0
    range_of_melody = 8
    Q_threshold_low = 11
    Q_threshold_high = 11 
    range_threshold_low = 5
    range_threshold_high = 6
    

    while ((Q<Q_threshold_low) | (Q>Q_threshold_high)) | (Rep>4) | (leap_step_ratio>0.2) |  (leap_step_ratio<0.1) | ((range_of_melody<range_threshold_low) | (range_of_melody>range_threshold_high)) :
        Q = 0
        Rep = 0
        Leap = 0
        Step = 0
        range_of_melody = 0
        start_note = "1"
        #print("Start Note", start_note)

        notes_in_prog = chord_sequence.loc[my_prog["Continuation1"][0]]
        target_notes = []

        for i in range(9):
            if notes_in_prog[i]!="":
                target_notes.append(chord_sequence.columns[i])

        #print(target_notes)
        target_start = target_notes[random.randint(1, len(target_notes))-1]
        #print("Target-Start", target_start)

        start_notes_df = start_df[start_df["Hedef"]==target_start]
        start_notes = start_notes_df.iloc[[(random.randint(1, len(start_notes_df))-1)]]
        #print("\n",start_notes,"\n")
        Q = Q + start_notes.iloc[0]["Q"]
        Rep = Rep + start_notes.iloc[0]["Rep"]
        Leap = Leap + start_notes.iloc[0]["Leap"]
        Step = Step + start_notes.iloc[0]["Step"]
        
       

        # Continuation-1 Cell
        notes_in_prog = chord_sequence.loc[my_prog["Continuation2"][0]]
        target_notes = []
        for i in range(9):
            if notes_in_prog[i]!="":
                target_notes.append(chord_sequence.columns[i])

 
        target_continue_1 = target_notes[random.randint(1, len(target_notes))-1]
    
    
    
        continuation_1_1_notes_df = continue_df[(continue_df["Bir"]==target_start) & (continue_df["Hedef"]==target_continue_1)]
        continuation_1_2_notes_df = continue_df[(continue_df["Bir"]=="nan") & (continue_df["ve"]==target_start) & (continue_df["Hedef"]==target_continue_1)]
        continuation_1_3_notes_df = continue_df[(continue_df["Bir"]=="nan") & (continue_df["ve"]=="nan") & (continue_df["Ki"]==target_start) & (continue_df["Hedef"]==target_continue_1)]
        continuation_1_notes_df = pd.concat([continuation_1_1_notes_df,continuation_1_2_notes_df, continuation_1_3_notes_df])  
    
        if len(continuation_1_notes_df)>0:
            continuation_1_notes = continuation_1_notes_df.iloc[[(random.randint(1, len(continuation_1_notes_df))-1)]]
            Q = Q + continuation_1_notes.iloc[0]["Q"]
            Rep = Rep + continuation_1_notes.iloc[0]["Rep"]
            Leap = Leap + continuation_1_notes.iloc[0]["Leap"]
            Step = Step + continuation_1_notes.iloc[0]["Step"]
        else:
            Q = -100

        #print("Continuation Leap: ", Leap, "Contiunation 1 Step: ", Step)    

        # Continuation-2 Cell
        notes_in_prog = chord_sequence.loc[my_prog["Cadence1"][0]]
        target_notes = []
        for i in range(9):
            if notes_in_prog[i]!="":
                target_notes.append(chord_sequence.columns[i])

        #print(target_notes)
    
        target_continue_2 = target_notes[random.randint(1, len(target_notes))-1]
        #print("Target-Continuation2", target_continue_2)

        continuation_2_1_notes_df = continue_df[(continue_df["Bir"]==target_continue_1) & (continue_df["Hedef"]==target_continue_2)]
        continuation_2_2_notes_df = continue_df[(continue_df["Bir"]=="nan") & (continue_df["ve"]==target_continue_1) & (continue_df["Hedef"]==target_continue_2)]
        continuation_2_3_notes_df = continue_df[(continue_df["Bir"]=="nan") & (continue_df["ve"]=="nan") & (continue_df["Ki"]==target_continue_1) & (continue_df["Hedef"]==target_continue_2)]
        continuation_2_notes_df = pd.concat([continuation_2_1_notes_df,continuation_2_2_notes_df, continuation_2_3_notes_df])  
    
    
        #print("Boyut Continuation 2",  len(continuation_2_notes_df))
    
        if len(continuation_2_notes_df)>0:
            continuation_2_notes = continuation_2_notes_df.iloc[[(random.randint(1, len(continuation_2_notes_df))-1)]]
            #print("\n",continuation_2_notes,"\n")
            Q = Q + continuation_2_notes.iloc[0]["Q"]
            Rep = Rep + continuation_2_notes.iloc[0]["Rep"]
            Leap = Leap + continuation_2_notes.iloc[0]["Leap"]
            Step = Step + continuation_2_notes.iloc[0]["Step"]
        else:
            Q = -100    

        #print("Continuation2 Leap: ", Leap,"Continuation 2 Step: ", Step)    
            
        # Cadence-1 Cell
        notes_in_prog = chord_sequence.loc[my_prog["Cadence2"][0]]
   
        #print(target_notes)
        target_cadence_1 = target_notes[random.randint(1, len(target_notes))-1]
        #print("Target-Cadence1", target_cadence_1)

        cadence_1_notes_df = cadence_df[(cadence_df["Bir"]==target_continue_2)]

        continuation_2_1_notes_df = cadence_df[(cadence_df["Bir"]==target_continue_2)]
        continuation_2_2_notes_df = cadence_df[(cadence_df["Bir"]=="nan") & (cadence_df["ve"]==target_continue_2)]
        continuation_2_3_notes_df = cadence_df[(cadence_df["Bir"]=="nan") & (cadence_df["ve"]=="nan") & (cadence_df["Ki"]==target_continue_2)]
        continuation_2_notes_df = pd.concat([continuation_1_1_notes_df,continuation_1_2_notes_df, continuation_1_3_notes_df])  
  
        #print("Boyut Cadence 1",  len(cadence_1_notes_df))
    
        if len(cadence_1_notes_df)>0:
            cadence_1_notes = cadence_1_notes_df.iloc[[(random.randint(1, len(cadence_1_notes_df))-1)]]
            #print("\n",cadence_1_notes,"\n")
            Q = Q + cadence_1_notes.iloc[0]["Q"]
            Rep = Rep + cadence_1_notes.iloc[0]["Rep"]
            Leap = Leap + cadence_1_notes.iloc[0]["Leap"]
            Step = Step + cadence_1_notes.iloc[0]["Step"]
        else:
            Q = -100
    
        #print("Cadence Leap: ", Leap, "Cadence Step: ", Step) 
        
        
        leap_step_ratio = Leap/Step
            
                
        melody_df = start_notes
        melody_df = melody_df.append(continuation_1_notes)
        melody_df = melody_df.append(continuation_2_notes)
        melody_df = melody_df.append(cadence_1_notes)
        
        range_of_melody = total_range(melody_df)
  
 
    
    
    print("Q Değeri: ", Q)
    print("Leap/Step Değeri: ", leap_step_ratio)
    print("Rep Değeri: ", Rep)
    print("Leap Değeri: ", Leap)
    print("Step Değeri: ", Step)
    print("Range is ", range_of_melody)
    #print(melody_df)
    melody_np = melody_df.to_numpy()
    #print(melody_np)
    
       
    tie_yes_no, s = write_score(melody_df)
    s_alt = write_score_es(melody_df)
    s_alt.insert(0, meter.TimeSignature('4/4'))
    
    
    if tie_yes_no:
        melodies_with_tie.append(melody_np)
        with_tie_count = with_tie_count + 1 
        midifile_name = f"Melody_Progression_{selected_chord_prog:0=2d}_with_tie{with_tie_count:0=2d}.mid"
    else:
        melodies_no_tie.append(melody_np)
        no_tie_count = no_tie_count + 1
        midifile_name = f"Melody_Progression_{selected_chord_prog:0=2d}_no_tie{no_tie_count:0=2d}.mid"
        # To write midi file
        mf = midi.translate.streamToMidiFile(s_alt)
        mf.ticksPerQuarterNote = 512
        mf.open(midifile_name, 'wb')
        mf.write()
        mf.close()   


  
    
print("With tie:", len(melodies_with_tie) , "No Tie : ", len(melodies_no_tie))

pickle_name = f"No_ties_Progression_{selected_chord_prog:0=2d}"      
with open(pickle_name, "wb") as fp:   
    pickle.dump(melodies_no_tie, fp)
      
pickle_name = f"With_ties_Progression_{selected_chord_prog:0=2d}"      
with open(pickle_name, "wb") as fp:   
    pickle.dump(melodies_with_tie, fp)
# Out:
# Chord Progression:  6
# ________________________________
# Melody Count is:  0
# C:\Users\yavuz\AppData\Local\Temp/ipykernel_31520/1109125234.py:148: RuntimeWarning: divide by zero encountered in longlong_scalars
#   leap_step_ratio = Leap/Step
# Q Değeri:  11
# Leap/Step Değeri:  0.1
# Rep Değeri:  0
# Leap Değeri:  1
# Step Değeri:  10
# Range is  6
# ________________________________
# Melody Count is:  1
# Q Değeri:  11
# Leap/Step Değeri:  0.1111111111111111
# Rep Değeri:  1
# Leap Değeri:  1
# Step Değeri:  9
# Range is  6
# ________________________________
# Melody Count is:  2
# Q Değeri:  11
# Leap/Step Değeri:  0.125
# Rep Değeri:  2
# Leap Değeri:  1
# Step Değeri:  8
# Range is  5
# ________________________________
# Melody Count is:  3
# Q Değeri:  11
# Leap/Step Değeri:  0.1
# Rep Değeri:  0
# Leap Değeri:  1
# Step Değeri:  10
# Range is  6
# ________________________________
# Melody Count is:  4
# Q Değeri:  11
# Leap/Step Değeri:  0.125
# Rep Değeri:  2
# ...

# %%
for i in range(len(melodies_no_tie)):
   
    print("I", i)
    print(melodies_no_tie[i])
    
    s = write_score_no_tie(pd.DataFrame(melodies_no_tie[i], columns= ["Hücre", "Bir", "ve", "Ki", "ve2", "Hedef", "Step", "Leap", "Rep","Q"]))
       
    
        
    s.insert(0, meter.TimeSignature('4/4'))

    mf = midi.translate.streamToMidiFile(s)
    mf.ticksPerQuarterNote = 512
    
    #midifile_name = f"Melody_Progression_{selected_chord_prog:0=2d}_{melody_count+1:0=2d}.mid"
    pngfile_name = f"Melody_Progression_{selected_chord_prog:0=2d}_notie{i+1:0=2d}.png"
    #print("Midifile Name: ", midifile_name, "Image File Name: ",pngfile_name )
    #mf.open(midifile_name, 'wb')
    #mf.write()
    #mf.close()
    #s.show("lily.png")
    my_image = Image(filename=s.write("lily.png"))
    display(my_image)
    with open(pngfile_name, 'wb') as f:
        f.write(my_image.data)
    

    #s_alt = write_score_es(melody_df)
    #s_alt.insert(0, meter.TimeSignature('4/4'))

    #mf = midi.translate.streamToMidiFile(s_alt)
    #mf.ticksPerQuarterNote = 512
    
    #midifile_name = f"Alt_Melody_Progression_{selected_chord_prog:0=2d}_{melody_count+1:0=2d}.mid"
    #pngfile_name = f"Alt_Melody_Progression_{selected_chord_prog:0=2d}_{melody_count+1:0=2d}.png"
    #print("Midifile Name: ", midifile_name, "Image File Name: ",pngfile_name )
    #mf.open(midifile_name, 'wb')
    #mf.write()
    #mf.close()
    #s.show("lily.png")
    #my_image = Image(filename=s_alt.write("lily.png"))
    #display(my_image)
    #with open(pngfile_name, 'wb') as f:
    #    f.write(my_image.data)
    
    
print("-----------------------") 
print("-----------------------") 

'''
for i in range(len(melodies_with_tie)):
   
 
    print(melodies_with_tie[i])
    
    s = write_score(pd.DataFrame(melodies_with_tie[i], columns= ["Hücre", "Bir", "ve", "Ki", "ve2", "Hedef", "Step", "Leap", "Rep","Q"]))
       
    
        
    s.insert(0, meter.TimeSignature('4/4'))

    mf = midi.translate.streamToMidiFile(s)
    mf.ticksPerQuarterNote = 512
    
    #midifile_name = f"Melody_Progression_{selected_chord_prog:0=2d}_{melody_count+1:0=2d}.mid"
    pngfile_name = f"Melody_Progression_{selected_chord_prog:0=2d}_withtie{i+1:0=2d}.png"
    #print("Midifile Name: ", midifile_name, "Image File Name: ",pngfile_name )
    #mf.open(midifile_name, 'wb')
    #mf.write()
    #mf.close()
    #s.show("lily.png")
    my_image = Image(filename=s.write("lily.png"))
    display(my_image)
    with open(pngfile_name, 'wb') as f:
        f.write(my_image.data)
       
'''
# Out:
# I 0
# [[35 '1' 'nan' 'nan' '2' '3' 2 0 0 2]
#  [2632 '3' '1' '7' 'nan' '6l' 2 1 0 3]
#  [2787 '6l' '7' 'nan' '6l' '5l' 3 0 0 3]
#  [36 '5l' '6l' '7' 'nan' 1 3 0 0 3]]
# I 1
# [[135 '1' 'nan' '1' '2' '3' 2 0 1 3]
#  [2200 '3' 'nan' '4' '5' '4' 3 0 0 3]
#  [2544 '4' '2' '1' 'nan' '7' 2 1 0 3]
#  [23 '7' 'nan' '1' 'nan' 1 1 0 1 2]]
# I 2
# [[19 '1' 'nan' '2' 'nan' '1' 2 0 0 2]
#  [836 '1' '5' 'nan' 'nan' '4' 1 1 0 2]
#  [2916 '4' '3' '2' '1' '2' 4 0 0 4]
#  [48 '2' 'nan' '3' '2' 1 3 0 0 3]]
# I 3
# [[136 '1' 'nan' '1' '3' '3' 0 1 2 3]
#  [210 '3' 'nan' 'nan' '2' '1' 2 0 0 2]
#  [2719 '1' '7' '6l' 'nan' '5l' 3 0 0 3]
#  [36 '5l' '6l' '7' 'nan' 1 3 0 0 3]]
# I 4
# [[135 '1' 'nan' '1' '2' '3' 2 0 1 3]
#  [1798 '3' 'nan' '2' '1' '1' 2 0 1 3]
#  [2499 '1' '7' 'nan' '6l' '7' 3 0 0 3]
#  [22 '7' 'nan' 'nan' '2' 1 1 1 0 2]]
# I 5
# [[79 '1' 'nan' 'nan' '7' '6l' 2 0 0 2]
#  [1534 '6l' '7' 'nan' 'nan' '6l' 2 0 0 2]
#  [2576 '6l' '7' '1' 'nan' '7' 3 0 0 3]
#  [114 '7' '1' '2' '3' 1 3 1 0 4]]
# ...
